# %%
ecg_data='1114112,-1245183,-1179647,-1179646,-1179647,-1179648,-1179646,-1179647,-1179646,-1179646,-1245183,-1245184,-1245183,-1310718,-1310717,-1310717,-1245184,-1245181,-1179646,-1310719,-1048575,-655359,-1638400,-1638397,-1114110,-1179648,-1179648,-1179647,-1179646,-1179647,-1179646,-1114112,-1245181,-1179648,-1245181,-1179645,-1179645,-1179645,-1048576,-1114111,-1179646,-1179648,-1179647,-1179646,-1245182,-1179646,-1048576,-1114112,-1114111,-1114112,-1179645,-1114112,-1114112,-1114111,-1114110,-1048576,-1114111,-1114112,-1114111,-1114110,-1114112,-1114110,-1114109,-1114110,-1114111,-1114112,-1114112,-1179645,-1048575,-1048576,-1048574,-1048573,-1114110,-1179645,-1114111,-1114111,-1114111,-1114111,-1048576,-1048576,-1048574,-1245184,-1245183,-393213,-1179648,-1507325,-1114110,-1048575,-1114109,-1114109,-1114110,-1048575,-1048574,-1114110,-1048576,-1114111,-1114111,-1048576,-1048576,-1048576,-1048573,-1048573,-1048574,-1048574,-1048573,-1048574,-1179645,-1245182,-1245183,-1179648,-1179648,-1179647,-1179646,-1179646,-1114112,-1114111,-1179645,-1179647,-1179645,-1179647,-1114112,-1114109,-1179646,-1179648,-1114112,-1114112,-1179647,-1179645,-1114110,-1179645,-1114111,-1114110,-1114111,-1114109,-1114109,-1114109,-1048574,-1048576,-1114109,-1114109,-1048576,-1048576,-1114110,-1114111,-1114111,-1114111,-1048576,-1048576,-1179647,-524285,-786432,-1638398,-1114110,-1114109,-1114111,-1114112,-1114111,-1114111,-1048576,-1048575,-983039,-983039,-1048573,-983037,-1048576,-1048575,-983040,-1048575,-1114109,-1179645,-1179645,-1179645,-1179647,-1179645,-1114112,-1114110,-1048576,-1048576,-1048575,-1114109,-1048575,-1048576,-1048573,-983040,-1048574,-983039,-983040,-1048573,-1048573,-1048573,-983040,-983040,-983038,-983039,-983038,-983039,-983040,-917504,-917504,-1048576,-983038,-917504,-1048576,-1114111,-1114112,-1114112,-1114109,-1114110,-1179645,-1179645,-1114110,-1310718,-917501,-524285,-1245184,-1638398,-1310718,-1310717,-1179648,-1245183,-1245183,-1245181,-1245182,-1245183,-1245184,-1310719,-1245181,-1179647,-1245181,-1114112,-1114112,-1114109,-1048573,-983038,-1048574,-1114109,-1114111,-1114112,-1179646,-1179646,-1179646,-1179645,-1179645,-1179645,-1114111,-1048576,-1114110,-1179646,-1114110,-1114111,-1114112,-1114111,-1114111,-1179645,-1245181,-1245183,-1310717,-1310717,-1245183,-1310717,-1179648,-1179647,-1114109,-1048574,-1114109,-1048574,-1048574,-1114112,-1114112,-1114112,-1179647,-1114112,-1179645,-1179648,-1179647,-1179648,-1114112,-1310718,-851967,-655360,-1310718,-1507325,-1048574,-1179645,-1114111,-1114111,-1114111,-1179645,-1179647,-1179646,-1179647,-1179648,-1179647,-1179646,-1179647,-1114111,-1048575,-1179645,-1114112,-1114112,-1114111,-1048575,-1048576,-1048576,-1048576,-1048576,-1048575,-1114109,-1048573,-983039,-1048576,-1048576,-1048576,-1048575,-1048575,-1048575,-1048574,-1048575,-1048576,-1048574,-1114109,-1114112,-1179647,-1179646,-1179645,-1179646,-1114112,-1179645,-1114110,-1114110,-1114112,-1048575,-1114109,-1245181,-1179646,-1245182,-1179648,-1179648,-1245183,-1179647,-1114112,-983040,-1310719,-1245182,-458752,-1441789,-1376255,-1048576,-1114111,-1114109,-1048576,-1048574,-1048574,-1048576,-1048575,-1048574,-1048576,-1048575,-1048574,-1048575,-1048576,-1114111,-1114111,-1114110,-1114109,-1048575,-1114110,-1114111,-1114110,-1114112,-1245181,-1114111,-1114111,-1114111,-1114109,-1048576,-1114109,-1114110,-1048575,-1048573,-1114109,-1048574,-1114109,-1179645,-1114111,-1114112,-1179646,-1179646,-1179646,-1114109,-1114112,-1114111,-1114112,-1114112,-1114112,-1114109,-1114109,-1048576,-1179645,-1179647,-1114109,-1179647,-1179648,-1114111,-1048576,-1114112,-1048576,-1114109,-1114109,-1245184,-524285,-655359,-1703936,-1179645,-1048575,-1114112,-1114111,-1245181,-1179645,-1048576,-1114111,-1048576,-1048575,-1114111,-1048574,-1048574,-1114109,-1048574,-1114112,-1179647,-1179647,-1245184,-1245181,-1179648,-1310718,-1310719,-1310717,-1245182,-1179648,-1114112,-1179647,-1179645,-1114110,-1114109,-1114109,-1114109,-1048576,-1048576,-1114111,-1179646,-1114110,-1114110,-1179647,-1179647,-1179647,-1179647,-1245182,-1114110,-1179646,-1179645,-1114112,-1048576,-1048574,-1048575,-983037,-1114110,-1179646,-1048576,-1114110,-1179647,-1114112,-1114112,-1114112,-1114111,-1179645,-1179646,-1114111,-720894,-917501,-1572861,-983039,-983040,-1048574,-1048575,-983040,-983039,-983040,-983038,-983038,-983039,-917504,-983038,-983038,-983037,-983039,-983037,-917502,-983039,-917502,-983040,-1048574,-983039,-1048575,-1048576,-1048574,-1048574,-1048575,-983040,-983040,-983039,-983038,-983038,-983040,-983037,-917502,-917504,-983038,-983039,-983038,-983037,-983038,-983039,-983037,-917504,-1048573,-983037,-983037,-983039,-1048573,-983038,-983039,-1048575,-983039,-917504,-983037,-917504,-917503,-917504,-917504,-983038,-983038,-983037,-983039,-983039,-1048573,-1048574,-983040,-1179648,-917503,-524285,-1114110,-1441790,-1048576,-1048575,-1048575,-983039,-917504,-851968,-917502,-851968,-851968,-851968,-851968,-851965,-851966,-786432,-786432,-786432,-851965,-917501,-917504,-917501,-851965,-917502,-851968,-851965,-786430,-786432,-786430,-720896,-786430,-720894,-720896,-786430,-720894,-720893,-655359,-720894,-720894,-720894,-720895,-720893,-786430,-720894,-720894,-851965,-720896,-720896,-786432,-720896,-786431,-786429,-720896,-851967,-917501,-983038,-917504,-917503,-983038,-917504,-983037,-917504,-851967,-1048576,-327677,-196606,-1310720,-1114109,-917502,-917504,-917504,-917501,-917503,-917504,-917503,-917504,-917503,-917503,-917504,-917503,-917502,-851968,-917502,-917501,-851968,-917501,-917502,-917503,-983038,-983039,-983040,-983040,-983039,-917504,-983037,-917504,-983038,-983039,-983038,-983038,-983040,-1048575,-1048573,-983040,-1048573,-983038,-917504,-983038,-983038,-983037,-983037,-983037,-1048575,-1048574,-1048574,-1114109,-1048576,-1114110,-1114112,-1114109,-1048575,-983040,-983039,-1048575,-983040,-983038,-983038,-917503,-917504,-983037,-917503,-917501,-917502,-1048576,-524287,-655360,-1507327,-1245181,-983040,-1114110,-1114110,-1048576,-1179645,-1179646,-1179646,-1114109,-1114109,-1114110,-1114110,-1114109,-1048576,-1048576,-1048573,-1048576,-1114112,-1179645,-1114112,-1114110,-1048576,-1048573,-983040,-1048574,-1048576,-1048576,-1114110,-1048576,-1048573,-1114109,-1048575,-1114110,-1114109,-1114110,-1114110,-1114109,-1179645,-1114111,-1048573,-1048574,-1114109,-1048574,-1114111,-1114109,-1048575,-1048575,-1048574,-983039,-983038,-983040,-1048573,-983038,-1048574,-1048575,-1048576,-1114110,-1114109,-1114111,-1114111,-1048576,-1048575,-1114109,-1245181,-655359,-720894,-1310720,-1310718,-1048573,-1114109,-1048576,-1048574,-1048575,-983038,-983040,-983039,-983037,-983039,-983038,-983039,-917501,-786429,-458751,-131071,-65533,-65536,-458752,-917503,-1179645,-1245183,-1310718,-1376256,-1441792,-1507325,-1441790,-1245183,-1179647,-786432,-262143,-196605,-196607,-327680,-655358,-917502,-1048574,-1179648,-1310718,-1310717,-1245183,-1114109,-1048573,-1048574,-983040,-917503,-589824,-524286,-393216,-458750,-720895,-1114109,-1245182,-1572863,-1966077,-2228223,-2293757,-1900541,-1376253,-1245183,-1179648,-1310717,-1245184,-1245183,-1114111,-1310718,-983038,-655357,-1376253,-1572863,-1048575,-1114110,-1048574,-917504,-851965,-720895,-786432,-786431,-851967,-1048573,-1114109,-1179645,-1179648,-1376254,-1441789,-1441792,-1376256,-1310718,-1310717,-1310719,-1245182,-1179648,-1245183,-1245182,-1114110,-1048574,-1048573,-1048573,-1048575,-1048573,-1048573,-1048575,-1114110,-1048573,-1048575,-1179648,-1245183,-1310720,-1310718,-1245183,-1310720,-1441789,-1376254,-1245182,-1245183,-1114110,-983039,-1114111,-1114110,-1048575,-1048574,-1048574,-1048573,-1114109,-1048573,-983039,-983037,-1245182,-655358,-589824,-1179648,-1245184,-851968,-917501,-786429,-786431,-786432,-720896,-851968,-983038,-851967,-851965,-851967,-851967,-851966,-917501,-786432,-720893,-524286,-327678,-65535,-262142,-458749,-786432,-983037,-917504,-851967,-786431,-917501,-1048575,-1114111,-1048575,-983038,-917501,-983037,-1048574,-1114109,-1048575,-1048575,-1048575,-1048573,-1048574,-1114110,-1114111,-983040,-983040,-1048575,-1048573,-983040,-1048575,-983040,-917503,-917504,-851967,-983037,-983039,-1048576,-1048575,-983039,-1048574,-983039,-1048574,-1048576,-983038,-1114109,-983038,-393215,-1376254,-1507326,-917501,-1048573,-983040,-1048573,-983040,-983040,-983038,-1048576,-1048574,-1048574,-1048573,-1048574,-917503,-917503,-851968,-917503,-983038,-983040,-983039,-983038,-1048575,-983039,-983038,-983039,-983038,-1048574,-1048574,-983040,-1048573,-1048574,-1048573,-983039,-1114109,-983039,-983038,-983039,-983040,-983040,-1048573,-983040,-983038,-983040,-983040,-1048573,-1114109,-917504,-983038,-983039,-1048573,-1048576,-983039,-1048573,-1048574,-1048574,-983040,-983039,-1048573,-983037,-983038,-1114109,-327680,-1245181,-1507328,-983040,-1048575,-983040,-1114109,-1114110,-1048576,-1114109,-983040,-983040,-1048574,-1048573,-983039,-983038,-983039,-983037,-983040,-983039,-917501,-917503,-983039,-983039,-983039,-983040,-1048573,-1048576,-1048574,-1048573,-1114109,-983040,-983038,-983038,-983040,-1048574,-983037,-917504,-1048575,-1048573,-983040,-983039,-1048576,-1114110,-1048573,-983040,-917504,-983037,-983039,-1048573,-1048574,-983039,-983037,-1048573,-917503,-917503,-917504,-983038,-1048576,-1048573,-1048573,-983040,-1048573,-983039,-983037,-983040,-917504,-1048576,-720894,-327677,-1048575,-1376253,-917503,-917504,-917502,-983039,-917502,-917502,-917502,-851968,-917502,-917503,-917501,-851968,-917503,-786430,-917502,-851968,-983037,-1048574,-983037,-917504,-1048576,-917503,-917503,-983038,-917502,-851968,-917503,-917504,-983037,-917502,-917503,-917503,-917502,-917503,-917503,-917504,-983038,-917502,-917502,-917502,-917502,-917501,-917503,-917503,-917501,-917503,-851966,-851966,-983039,-983040,-1048574,-1048575,-1048575,-983040,-983040,-1048575,-983039,-1048575,-1179646,-196607,-393214,-1572861,-1048575,-983038,-1048573,-983038,-1048573,-1048576,-983038,-983039,-1048575,-983039,-983040,-1048576,-983040,-1048575,-1048574,-917502,-917502,-917502,-917501,-917503,-983039,-983038,-983038,-983038,-1048574,-983040,-1048575,-983038,-983039,-1048574,-983038,-983038,-1048573,-1048574,-917502,-917501,-917502,-917502,-917502,-917504,-917502,-851968,-917502,-917502,-851968,-851966,-851966,-851968,-851966,-917502,-786432,-851965,-917501,-851968,-917503,-983038,-983038,-1048573,-983038,-917503,-1048573,-917504,-983040,-786430,-393214,-1376256,-1310720,-851966,-917503,-851968,-917503,-917501,-851968,-917504,-917503,-851968,-917502,-917501,-917502,-917501,-851968,-851968,-917501,-917504,-983037,-983037,-917504,-917503,-917502,-851967,-851966,-851967,-851968,-851966,-917501,-851968,-917503,-917502,-917502,-917502,-917502,-917503,-851968,-917503,-917502,-917503,-983040,-917504,-917503,-917503,-917501,-917502,-917503,-917504,-917503,-917503,-917501,-786429,-786429,-851966,-851968,-917502,-917504,-917502,-917501,-917503,-917501,-851968,-851967,-983038,-589824,-262144,-1310718,-1245182,-786432,-917501,-851968,-917502,-917501,-851966,-917501,-851968,-786431,-851965,-851965,-786431,-851967,-851965,-720896,-786432,-786431,-720894,-786431,-851968,-917503,-983037,-917502,-917501,-786431,-851967,-786431,-786430,-851965,-786432,-786431,-851967,-786432,-786432,-851966,-851967,-851965,-851968,-917502,-786431,-851966,-917501,-786429,-786431,-851966,-786431,-786431,-786432,-786431,-851967,-851966,-786431,-851965,-851967,-786432,-786431,-720895,-786430,-720894,-786431,-786431,-851965,-851968,-720894,-786431,-851967,-851965,-851968,-786431,-196606,-589821,-1376256,-786429,-786431,-786432,-851965,-851965,-851965,-720893,-720895,-720894,-720895,-655358,-720894,-720896,-655360,-851965,-917501,-851968,-917504,-917502,-983037,-983040,-917504,-851968,-917504,-917504,-917502,-917502,-983038,-917502,-983038,-983039,-917502,-917502,-917502,-917504,-917504,-917502,-851968,-917501,-917502,-786431,-786432,-851968,-786431,-786429,-786432,-720895,-720893,-786429,-851966,-851968,-851968,-851967,-786432,-851966,-851966,-786432,-720894,-917503,-720894,-131070,-720893,-1310718,-851968,-917502,-851965,-917502,-983039,-983038,-917504,-917504,-917501,-720894,-851965,-786432,-720893,-720896,-720896,-720895,-786429,-720894,-655358,-851965,-851968,-786429,-786431,-786432,-720896,-720895,-720895,-720894,-720896,-720894,-720896,-720895,-720896,-786430,-786430,-851965,-720894,-786429,-786431,-786432,-720896,-720895,-786431,-786432,-851968,-786432,-720896,-851966,-851965,-720894,-720896,-786431,-720895,-720893,-720895,-655357,-720896,-851967,-851965,-851965,-851967,-851965,-851965,-917503,-786432,-917504,-983038,2,-983038,-1245184,-851967,-917502,-851968,-851966,-851966,-851965,-917504,-917502,-851968,-983039,-983037,-983038,-917503,-1048573,-1048573,-917503,-1114110,-1179645,-1048575,-1114109,-1114110,-1048573,-1048576,-1114109,-983039,-983040,-1048573,-983038,-983037,-983039,-983037,-983037,-917503,-917502,-917504,-983037,-917504,-851968,-851968,-917503,-851968,-917501,-851965,-786430,-786430,-786429,-786430,-786431,-851968,-851967,-851965,-851968,-786430,-851966,-851968,-851967,-983039,-851967,-327680,-851966,-1376255,-851966,-983038,-983040,-917503,-917501,-917504,-983038,-917503,-917503,-983038,-917503,-917504,-983039,-851968,-983039,-917504,-851968,-917502,-851968,-917503,-917502,-983039,-983039,-917502,-917504,-917504,-851968,-917504,-851967,-851966,-917504,-917503,-851968,-851967,-851968,-786432,-786431,-786431,-851968,-851967,-917501,-917502,-917502,-983037,-983038,-983039,-983037,-917502,-917503,-983037,-917504,-917501,-851967,-851967,-917501,-917504,-917504,-917502,-983038,-983038,-917502,-917503,-983040,-917504,-1114111,-393213,-458749,-1507326,-1048574,-1048575,-1114110,-1048574,-983037,-1048573,-1048573,-983038,-983038,-1048573,-983040,-983039,-1114110,-917501,-983040,-983039,-917504,-1048575,-1048575,-983038,-1048575,-1048574,-1048573,-1048576,-1048574,-1048574,-983040,-983039,-983040,-983039,-983040,-983037,-983038,-1048574,-983040,-983039,-1048575,-1048575,-1048575,-1048576,-1048574,-1048576,-1114111,-1114109,-983039,-983040,-983037,-917504,-1048575,-1048574,-983038,-983038,-1048574,-1048573,-983038,-1048576,-917504,-917504,-1179646,-393214,-983037,-1441791,-917504,-917504,-983040,-917501,-917504,-983039,-917504,-983037,-983040,-1048573,-983038,-983038,-983039,-917502,-983039,-917504,-851968,-917501,-917503,-851966,-917503,-917504,-917502,-983039,-1048573,-917504,-1048573,-983040,-983040,-983040,-983038,-917504,-851968,-917503,-917501,-851968,-917502,-917502,-917502,-983038,-983038,-983037,-983037,-983040,-983038,-1048574,-983038,-917503,-983037,-983037,-983037,-1048573,-917502,-851966,-786432,-851967,-851968,-983037,-1048574,-983037,-983037,-983040,-917504,-917504,-983039,-917504,-1048575,-720894,-589822,-1376254,-1245183,-917503,-983038,-1048573,-1048573,-983039,-983040,-983040,-983037,-983038,-917504,-917503,-983038,-917502,-983038,-917504,-983038,-917504,-1048573,-983038,-983038,-983037,-917502,-917504,-917504,-917504,-917503,-983037,-917504,-917501,-983038,-917504,-851967,-983038,-917504,-851968,-851966,-851966,-851967,-917502,-983038,-851967,-917502,-983038,-851968,-983039,-983039,-917504,-983037,-983039,-983037,-851968,-917503,-917501,-917504,-1048573,-1048573,-983037,-917504,-917503,-983037,-917504,-917503,-851966,-1114111,-458752,-983037,-1441792,-1048575,-917502,-851968,-983038,-917503,-917502,-917504,-917501,-917504,-983039,-917501,-917501,-917504,-983037,-917503,-917503,-851966,-786431,-851967,-851965,-851966,-917504,-917501,-917501,-983037,-917503,-917502,-917503,-983038,-917504,-983039,-983038,-917504,-983039,-983039,-917503,-983038,-983040,-983037,-917502,-983037,-983037,-917503,-983037,-917503,-917504,-983040,-1048574,-1048573,-1048573,-1114109,-1114110,-1114110,-1048573,-917502,-983037,-917503,-983037,-983040,-1048576,-1048573,-1048574,-1114111,-1048575,-1048573,-1048576,-983040,-1114112,-917504,-458751,-983037,-1441792,-983038,-1048576,-1114110,-1048574,-1048574,-1114110,-1048575,-1048575,-1114111,-1048575,-983040,-1114109,-1048576,-1048574,-1048574,-983039,-1114109,-1048575,-917502,-983037,-1048573,-917503,-983038,-983039,-917504,-983040,-1048574,-917504,-1048573,-1114111,-1114110,-1114112,-1114110,-1048576,-1048576,-1114111,-1114110,-1048575,-1048575,-1048576,-983040,-1048576,-1114109,-983039,-983040,-1048576,-983039,-983038,-1114111,-1048574,-1048576,-1114111,-1048574,-1048576,-1048576,-983039,-1048575,-1114110,-1048575,-1114109,-458750,-720894,-1572862,-983038,-983040,-983040,-1048573,-983040,-983039,-1048574,-1048574,-983040,-1114109,-1048574,-1048576,-1114112,-1114109,-1048575,-1048576,-983040,-983038,-983038,-983039,-1048573,-1048575,-1048576,-1048574,-1048575,-1048574,-983040,-1048575,-1048575,-983040,-983040,-1048574,-983038,-917504,-1048574,-1048574,-917504,-1048576,-1114111,-1048574,-1048574,-1048576,-1048574,-1048575,-1048575,-983039,-983038,-1048574,-1048573,-983039,-1048574,-1048573,-1048573,-1114110,-1048574,-1048574,-1048576,-1114109,-1114110,-1179645,-1114111,-1048573,-1114109,-1048576,-1048574,-1114110,-1048573,-1114112,-917502,-458752,-1048575,-1376254,-1048573,-1048574,-1048574,-983039,-983039,-983039,-983040,-983038,-917502,-983039,-983037,-917504,-983040,-983037,-983037,-917503,-917501,-917503,-917502,-917504,-917501,-917503,-917503,-851967,-983037,-917502,-917502,-983039,-983037,-917501,-983037,-983037,-851968,-983040,-1048573,-917503,-983038,-1048574,-1048573,-983038,-1048574,-1048574,-1048573,-1048574,-983040,-1048573,-1114109,-983040,-1048573,-983039,-983037,-983039,-983040,-1114110,-983040,-1048573,-983039,-983037,-1048574,-1048573,-1048575,-1114110,-1048573,-1048574,-983040,-983040,-917504,-851968,-1179646,-917501,-393214,-1376255,-1310720,-917501,-1048574,-983038,-983038,-983039,-983040,-983037,-983038,-983037,-917504,-983040,-1048575,-917502,-851968,-983038,-983037,-983039,-1048576,-983039,-983038,-1048573,-1048573,-983040,-1048575,-983040,-983039,-1048573,-983039,-983040,-1048576,-983038,-983039,-1048574,-1048573,-1048573,-1048574,-1048573,-983037,-1048573,-1048575,-983040,-1048574,-983040,-1048573,-1048574,-1114109,-983039,-983037,-983040,-917503,-983039,-1048576,-1048573,-1048575,-1048575,-983039,-1048573,-1048573,-1048574,-917503,-1245181,-458749,-917502,-1441792,-1114110,-983037,-1048573,-1048573,-917504,-983037,-983040,-917501,-917504,-1048575,-1048573,-983038,-983040,-983037,-983037,-983038,-917503,-983038,-917504,-983037,-917503,-983040,-983040,-983037,-1048573,-1048574,-983038,-1048573,-983039,-917503,-983038,-983039,-917504,-983038,-1048573,-983039,-1048575,-1048575,-983039,-983039,-1048573,-917504,-983038,-983039,-917504,-917504,-983037,-917503,-983039,-983037,-917504,-983037,-983040,-983037,-851968,-917501,-983039,-917504,-917503,-917503,-917501,-917504,-917504,-917503,-983039,-917503,-983037,-983040,-458751,-1376253,-1441791,-917502,-983037,-917504,-983040,-851968,-851966,-983037,-917502,-917501,-983037,-917504,-983039,-1048574,-983038,-917504,-983038,-917504,-1048574,-1048574,-1048573,-917504,-983040,-983039,-983040,-1048574,-983039,-983039,-983040,-917503,-983038,-1048575,-1048573,-1048573,-1048573,-983039,-917503,-983040,-917502,-917502,-983038,-851968,-917501,-917504,-917503,-851968,-917504,-983037,-917503,-917503,-983038,-983037,-917502,-917502,-1048574,-1048576,-1048576,-1048573,-1048573,-1048576,-983038,-983038,-1114110,-1048573,-1114112,-851968,-589824,-1114112,-1376256,-917503,-983040,-1048574,-983039,-1048573,-1048575,-917504,-983038,-1114109,-1048576,-983040,-1048573,-1048573,-917504,-983040,-1048573,-917502,-917504,-983038,-983038,-983039,-1048574,-983040,-983037,-983038,-983038,-917504,-983038,-983037,-917503,-983040,-917504,-917504,-1048574,-1048575,-983038,-1048573,-983040,-1048575,-1114112,-1048575,-1048573,-983040,-1114109,-983038,-983038,-1048573,-917504,-983037,-983039,-983039,-983040,-1048574,-1048574,-1048575,-1048574,-1048575,-1048573,-1114111,-1114112,-1048576,-1114110,-1048576,-1048574,-1048574,-1114109,-983039,-1179648,-393213,-458751,-1507328,-1048574,-983040,-1048574,-1114110,-1114109,-1048576,-1048575,-1048575,-1048576,-1048576,-1048573,-1048573,-1048575,-983037,-983037,-983040,-1048573,-1114110,-1048576,-1048576,-1114109,-1114109,-1048574,-1114110,-1114111,-983040,-1048573,-1048575,-1048573,-1048574,-1114109,-1048574,-1048573,-1114110,-1048574,-1048574,-1114109,-1114109,-1048575,-1048576,-1179647,-983040,-1048574,-1048575,-1048574,-1048576,-983040,-983039,-1114109,-1048575,-917504,-1048573,-983038,-983037,-1048575,-1048576,-983040,-983040,-1048575,-1048573,-983039,-983039,-917504,-1114109,-983039,-524287,-1048573,-1507326,-1114110,-1048574,-1048575,-1048574,-983038,-983039,-983040,-917503,-983040,-983038,-917502,-983039,-983040,-983038,-983039,-983039,-917503,-983038,-983039,-917501,-1048573,-1048576,-983039,-983039,-1048575,-983038,-983037,-983038,-983037,-917502,-983039,-917504,-851968,-917504,-917502,-917503,-983037,-983039,-983039,-1048573,-1114109,-1048574,-1048574,-983040,-917502,-983038,-983037,-917503,-983037,-917504,-917502,-917504,-983040,-917501,-917503,-1048573,-1048573,-983040,-917501,-917504,-983038,-983039,-983038,-917502,-983039,-917504,-917501,-983038,-917503,-917504,-1048574,-524286,-851966,-1572864,-1048575,-1048574,-1114112,-1048575,-917504,-983039,-1048573,-917503,-917503,-983039,-917504,-983037,-983039,-917504,-917503,-983037,-983038,-983039,-1048576,-1048575,-983039,-1114111,-1114109,-1048574,-1048576,-1048574,-1048573,-1048574,-1048575,-1048574,-917503,-983039,-983039,-983037,-983040,-983037,-983038,-983039,-917503,-983039,-1048573,-1048573,-983039,-1114112,-1114109,-1048574,-1114111,-1114111,-1048574,-1048574,-1114112,-1114110,-1048574,-1048576,-1048574,-1048573,-1048575,-983038,-1048573,-1114110,-983040,-983039,-983038,-1245181,-458751,-262143,-1310719,-1179646,-917504,-1114110,-1048576,-1048576,-983039,-1048574,-1114112,-1179646,-1114111,-1114109,-1048575,-1048574,-1048576,-1048574,-917503,-917504,-983038,-851965,-851967,-983038,-917504,-1048574,-1048576,-917504,-983039,-983040,-1048573,-1048574,-1048574,-983040,-1048573,-1048575,-983037,-917501,-983039,-983038,-917504,-917503,-917502,-917504,-983037,-1048574,-983038,-1048574,-1048574,-917503,-983040,-1048575,-1048573,-1048575,-1048576,-1048575,-1114109,-1179646,-1048576,-1048575,-1245181,-1179646,-1114109,-1048573,-917502,-786429,-524288,-262144,-262142,-131071,-393216,1,65539,-1114110,-1179646,-1048575,-1179645,-1114109,-1048576,-1048574,-851968,-917502,-983040,-1048573,-1245184,-1310720,-1245184,-1245182,-1179646,-1114110,-1179645,-1114110,-1114111,-1179645,-1179645,-1114111,-1114111,-1114109,-1114112,-1114112,-1179646,-1179647,-1179646,-1245182,-1114112,-1114109,-1179646,-1179645,-1114112,-1114110,-1048576,-1179645,-1179645,-1114111,-1179648,-1245184,-1245182,-1179648,-1245183,-1179648,-1179645,-1179647,-1179647,-1179645,-1114112,-1179646,-1114112,-1114111,-1114110,-1179645,-1179646,-1179647,-1114110,-1114109,-1179646,-1114112,-1114110,-1114111,-1179646,-1048574,-655357,-851967,-1572862,-1310720,-1114109,-983039,-1114112,-1179646,-1114111,-1179645,-1179646,-1114109,-1114110,-1179647,-1114109,-1114111,-1114112,-1048576,-1114110,-1114109,-1048575,-983037,-1048574,-1114111,-1114110,-1114112,-1114110,-1114112,-1114112,-1179648,-1179645,-1179646,-1179645,-1179645,-1245182,-1114112,-1114112,-1179647,-1179645,-1114110,-1114111,-1179645,-1114110,-1179647,-1179648,-1114112,-1245181,-1245184,-1179646,-1179645,-1245181,-1114112,-1179645,-1179648,-1179647,-1179646,-1245184,-1114110,-1048573,-1048575,-1114112,-1179648,-1245184,-1245183,-1245183,-1310717,-1245182,-1179646,-1245182,-1179647,-1048574,-1114111,-1245184,-458750,-1245183,-1572864,-983040,-1114109,-1048576,-983039,-1114111,-1114109,-1048573,-1179645,-1114111,-1114112,-1114112,-1114109,-1048574,-1048575,-1048575,-1048573,-1179647,-1114112,-1048574,-1114112,-1048575,-1114109,-1376255,-1376255,-1179646,-983037,-917502,-917503,-917502,-983037,-983037,-851968,-983037,-983039,-983037,-983037,-983038,-983038,-983040,-983038,-983038,-983039,-983039,-983037,-983038,-1048574,-983039,-983040,-1048575,-1048573,-1048575,-983038,-983040,-1048574,-1114109,-1048576,-1114111,-1114109,-1048574,-1048575,-1114110,-1048575,-1179645,-1179646,-262143,-720893,-1638399,-983040,-1114109,-1179645,-1114109,-1048575,-1048576,-1048574,-1048573,-1114109,-1114112,-1114109,-1114112,-1114110,-983040,-1048573,-1114109,-1048573,-983040,-1048574,-983040,-1048574,-1114111,-1114109,-1048573,-1114109,-1048575,-1048574,-1048576,-1048573,-1048573,-1048573,-983038,-1048574,-1114112,-1114109,-1114110,-1179646,-1114109,-1048575,-1048576,-1114110,-1048575,-1048575,-1114110,-1048576,-1114109,-1114112,-1114110,-1048575,-1179646,-1114111,-983037,-786430,-851965,-917504,-1048573,-983040,-1048573,-1048575,-1114109,-1114109,-1048575,-1048573,-1048573,-1048576,-983037,-458751,-851968,-1507326,-917502,-983040,-983040,-983037,-983037,-983040,-983038,-1048573,-1048576,-983040,-1048573,-1048575,-1048574,-983038,-983037,-983037,-1048576,-1048576,-1048574,-1048576,-1048575,-917504,-983039,-917503,-917502,-983038,-983037,-983037,-983040,-983039,-983038,-1048575,-1048576,-1048576,-1048575,-1048575,-1048573,-983039,-1048574,-1048574,-983038,-983040,-1048575,-1048574,-1048574,-1048574,-1048575,-983040,-983039,-1048573,-983038,-917502,-917503,-983040,-1048576,-1114109,-1114110,-1048576,-983038,-1048574,-1048575,-983039,-1114109,-1179645,-655359,-655359,-1572863,-1245183,-983038,-1048576,-983039,-983040,-1048576,-983039,-1048574,-1114109,-1048573,-983040,-1114110,-1048574,-983040,-1048575,-983040,-983039,-983039,-983037,-983037,-1048575,-1048576,-983040,-1048573,-1048574,-983039,-983039,-983039,-983037,-917504,-917504,-983037,-983038,-983039,-983037,-983040,-1048574,-1048573,-1048574,-1048575,-1048574,-983038,-1048575,-1048574,-983037,-1048576,-1048575,-983038,-1048574,-983040,-983038,-1048574,-1048574,-983040,-1048573,-983040,-851968,-917502,-983040,-983040,-1048574,-1048574,-1048573,-983037,-983038,-983038,-851968,-1179645,-1179647,-393214,-1179645,-1441789,-1048575,-1048575,-983040,-983040,-1048574,-983040,-983039,-1048576,-983040,-917504,-1048574,-983040,-983038,-851968,-917502,-983039,-983039,-983039,-1048575,-1048573,-983038,-983039,-917504,-983037,-983037,-983038,-983038,-983038,-1048573,-917504,-983037,-983040,-983039,-917504,-917504,-1048573,-983039,-983038,-983038,-917504,-917504,-983039,-917503,-983037,-983039,-983038,-983037,-983039,-983039,-1048574,-1048574,-917502,-983038,-1048576,-1048575,-1048575,-983040,-1048575,-983039,-1048576,-1048573,-851968,-1245183,-1114111,-65536,-1310717,-1638397,-1114109,-1179645,-1048574,-1048574,-1114109,-1114111,-1114110,-1114110,-1048574,-1114111,-1048576,-1114111,-1048574,-1114110,-1114110,-1048573,-1114109,-1048574,-983038,-983039,-1114109,-1179646,-1179645,-1114112,-1048576,-983040,-1114110,-1048573,-1048573,-1114111,-983039,-983039,-1114109,-1114109,-1048573,-1048575,-1114111,-1048575,-1114109,-1114110,-1114110,-1114110,-1114109,-1114109,-1048573,-1114110,-1048576,-1048575,-1114109,-983040,-983039,-1048576,-1048574,-1114110,-1114111,-1179645,-1179645,-1114112,-1114109,-1048575,-1048574,-1245181,-393215,-720895,-1376256,-1114109,-917502,-983040,-917501,-917504,-983040,-917503,-1048574,-1048576,-1048576,-1114109,-1048576,-1048576,-983040,-1048573,-983040,-1114111,-1114109,-1048575,-1114111,-1048576,-1048574,-1114111,-1114110,-1048573,-1048574,-1048574,-983038,-983039,-983040,-1048574,-917503,-983040,-1048573,-1048574,-1114110,-983039,-1048574,-1114111,-983040,-1048576,-1114111,-1048575,-1048575,-1114109,-1048574,-983037,-1048575,-1048575,-917502,-983039,-1048575,-1048573,-1114110,-1179645,-1048575,-1114111,-1179646,-983040,-1114112,-1114111,-1310717,-983040,-458749,-1507326,-1638398,-983039,-1048576,-1048573,-1114109,-1048575,-1048574,-1114111,-1048575,-1048575,-1114111,-1114112,-1048576,-1114111,-1114110,-1048576,-1048575,-983040,-983040,-1048574,-1048574,-1048574,-1048575,-1048576,-983037,-1048573,-983040,-917504,-1048574,-1048576,-983037,-1048575,-1048575,-1048575,-1048576,-1114111,-1048576,-1048573,-1114110,-1114109,-1048574,-1048574,-983038,-917502,-1048573,-983039,-983038,-983039,-983037,-917503,-917501,-917503,-1048575,-1048576,-1048574,-983040,-917504,-1048573,-1048573,-983038,-1048576,-983038,-1179648,-458752,-327677,-1507325,-1179647,-1048576,-1048575,-983040,-1048574,-917504,-983038,-983040,-983037,-983038,-983037,-917503,-983039,-917502,-917502,-983038,-983037,-1048573,-1114110,-1114111,-1114111,-1048575,-1114109,-983039,-1048575,-1048576,-983040,-1114109,-1048574,-1048574,-1048575,-983038,-1048573,-1048575,-1048575,-1048574,-1048575,-1048575,-1048574,-1048576,-1048576,-1114109,-1179645,-1114111,-1048575,-1114109,-1114109,-983039,-1114110,-1048574,-917504,-1114111,-1114112,-1179646,-1179648,-1179647,-1179645,-1114111,-1114112,-1114110,-1114109,-1310719,-655358,-786431,-1572863,-1245183,-1048575,-1114111,-1179645,-1048574,-1048576,-1114109,-1048574,-1048576,-1048574,-1048574,-1048575,-1048575,-983040,-983039,-983039,-917504,-917503,-983037,-917504,-983040,-1114110,-983039,-1048574,-1179645,-1114112,-1114109,-1179645,-1179645,-1048574,-1114109,-1048575,-1114109,-1114109,-1114110,-1048573,-1114111,-1048576,-983039,-1179645,-1114111,-1048573,-1048574,-1114110,-1048574,-1048575,-1179645,-1048576,-1048574,-1114110,-1048573,-983040,-1114109,-983039,-983039,-1114110,-1048575,-1048576,-1179646,-1114111,-1048575,-1179647,-1114112,-1114110,-1179645,-1310718,-393216,-655357,-1638399,-983040,-1048574,-1114110,-1048576,-1048576,-1048574,-917504,-1114111,-1114109,-1048576,-1114109,-1048575,-1048576,-1114110,-1048576,-983037,-1048575,-1179647,-1114111,-1179645,-1114112,-1048576,-1179645,-1179646,-1114111,-1114112,-1114109,-1114109,-1114109,-1114109,-1114109,-1114109,-1048573,-983040,-983039,-1048574,-1048573,-1048576,-1048574,-983038,-983040,-1048576,-1048576,-1048575,-1114110,-1114110,-1114110,-1114112,-1048575,-1048575,-1114111,-1114110,-1114111,-1179646,-1179647,-1179646,-1179647,-1179648,-1048576,-1179648,-1179648,-1114109,-1376255,-589823,-1179645,-1638400,-1245182,-1245181,-1114111,-1114111,-1114112,-1048576,-1114111,-1114112,-1048575,-1114110,-1114109,-1048574,-1048576,-1114109,-1048574,-1048576,-1048576,-1048576,-1114109,-1048576,-1114112,-1114110,-1114110,-1048576,-1114109,-1114110,-1048576,-1114109,-1114110,-1048573,-1114111,-1114112,-1179647,-1114112,-1179646,-1179646,-1048576,-1179646,-1114112,-1114109,-1179646,-1114110,-1048575,-1179646,-1114110,-983039,-1114110,-1114112,-1048574,-1114109,-1179646,-1114110,-1114109,-1114110,-1048575,-1048574,-1048574,-1114110,-1114109,-1114112,-1114109,-1114110,-1179645,-1114109,-1114110,-1114110,-1114111,-1245183,-851967,-655357,-1245183,-1507326,-1048574,-1179646,-1179647,-1048576,-983040,-1114110,-1114112,-1048575,-1048576,-1048573,-983038,-1048576,-917504,-917504,-1048573,-1048573,-1114110,-1114110,-1114109,-1048574,-1114112,-1114111,-1048574,-1114110,-1048575,-1048575,-1114112,-1179645,-1048575,-1179645,-1179646,-1048575,-1114111,-1114111,-1114109,-1179646,-1179645,-1048576,-1114110,-1114109,-1048575,-1048576,-1114111,-1048576,-1114109,-1114111,-1114109,-1114112,-1179648,-1114109,-1048576,-1179645,-1048576,-1114109,-1179647,-1179645,-1114111,-1114112,-1179645,-1048575,-1114111,-1114111,-983037,-1310717,-851967,-458750,-1310719,-1441792,-1048574,-1179646,-1114112,-1048575,-983039,-1114111,-1114109,-1048573,-1114111,-1048573,-1048575,-1114109,-1114110,-1114110,-1048574,-1114110,-1048573,-983039,-983037,-1048575,-1114110,-1114110,-1048576,-1114110,-1114109,-983038,-1048574,-1114109,-983037,-1048573,-1114109,-983038,-1048576,-1179646,-1114109,-1048576,-1179646,-1114111,-1114111,-1114111,-1048575,-983037,-1048576,-1114109,-1114109,-1114110,-1048575,-1114109,-1114110,-1114110,-1114109,-1048573,-1048574,-1048574,-1048576,-1114110,-1114110,-1114111,-1114109,-1114109,-983040,-1048576,-1048576,-1245181,-917502,-327680,-1048573,-1638400,-1245182,-1179646,-1179648,-1114109,-1048576,-1179646,-1114109,-1114110,-1245181,-1114112,-1048574,-1114111,-1114112,-1048575,-1048574,-983037,-1114110,-1114110,-1048575,-1114110,-1114110,-1048576,-1048574,-1048573,-1048575,-983039,-1048574,-1048573,-983038,-1048576,-983040,-983039,-1048574,-1048573,-1048575,-1048576,-1048575,-1048575,-1114110,-1114111,-1114110,-1114112,-1114109,-1048576,-1114110,-1114111,-983040,-1048575,-1048574,-917504,-1048573,-1114112,-1048573,-1048574,-1114111,-1048575,-1048576,-1048576,-1048574,-983039,-1048575,-1179648,-458751,-458750,-1441789,-1114110,-983040,-1048575,-1048574,-1048573,-1114109,-1048575,-1048575,-1114110,-1048574,-1114109,-1114110,-1048574,-1114109,-1048575,-1048574,-983037,-983038,-917502,-983038,-1048576,-983040,-1048574,-1114110,-1114110,-1114110,-1114111,-1114110,-1114109,-1114109,-1048576,-983040,-1114110,-1048575,-983038,-1048576,-1114110,-983039,-1114110,-1114110,-983040,-1048576,-1114112,-1048574,-1048575,-1114111,-1114110,-1048576,-1048575,-1114109,-983040,-1114109,-1048575,-983039,-1048575,-1048573,-1048576,-1114111,-1048575,-1114111,-1114110,-1179646,-1114112,-1048574,-1114111,-983040,-1114112,-1048576,-327680,-1376255,-1507327,-917502,-1114109,-1114110,-1048573,-1048573,-983038,-917502,-983039,-1048573,-1048576,-1048574,-1048576,-1048574,-1048575,-983040,-983038,-1048573,-1048574,-1048576,-1114110,-1048576,-983039,-1048574,-1114111,-1048575,-1114110,-1048575,-1048573,-1114110,-1048576,-1048574,-1048573,-1114111,-1114109,-1048574,-1114109,-1048573,-983040,-1048574,-917504,-1048573,-1048576,-1048573,-1048573,-1048574,-983039,-983038,-1048575,-983039,-1114109,-1179645,-983039,-983038,-1048576,-1114109,-1048576,-1114110,-1114111,-983040,-1048576,-1114109,-1048575,-1114111,-1245182,-327680,-720895,-1638399,-1048575,-1048576,-1114110,-1048576,-983039,-1048574,-983040,-1048575,-1114110,-1048575,-983039,-1114111,-1048575,-1048575,-1114110,-1114110,-1048574,-1048574,-983039,-983040,-1048576,-1114109,-983040,-1048576,-1048576,-983040,-1048574,-1114109,-1048573,-1114110,-1114110,-1114111,-1048575,-1048576,-1114109,-983040,-1048576,-1048576,-983037,-1048574,-1114109,-983039,-1048576,-1114109,-1048574,-1048576,-1114112,-1048576,-1048575,-1048573,-983039,-1048574,-1114112,-1114112,-1048575,-1114112,-1114110,-1048574,-1114111,-1048576,-1048573,-1310717,-1048573,-327678,-1441792,-1376254,-983037,-1114112,-1114111,-1048573,-1114109,-1048575,-1048573,-1114110,-1048576,-983039,-983040,-1048573,-917503,-1048575,-983039,-1114110,-1179647,-1114111,-1114112,-1179646,-1179645,-1048574,-1048576,-1114110,-1048575,-1114110,-1114111,-1114112,-1114112,-1048576,-1114111,-1179647,-1179648,-1179647,-1179648,-1179646,-1114110,-1114110,-1114110,-1048573,-1114109,-1048573,-983039,-1114112,-1114112,-1114109,-1114109,-1114109,-1048573,-983040,-1114110,-1114110,-1048575,-1114112,-1048576,-1048576,-1048575,-1048575,-983037,-1048573,-983038,-1114109,-458752,-589823,-1441791,-1048573,-1114112,-1048574,-1048576,-1114112,-1048575,-1114110,-1114109,-1048573,-1048573,-983040,-983038,-983037,-917504,-851967,-917503,-917501,-786432,-851967,-917501,-851967,-917504,-983038,-983039,-983038,-917503,-917502,-851965,-851965,-851966,-786429,-720896,-786432,-786429,-786432,-851965,-786429,-786431,-851967,-786431,-786432,-917502,-917501,-851968,-851967,-917501,-917504,-983038,-917502,-917501,-983037,-917504,-917502,-917502,-851968,-917504,-983038,-983040,-1048573,-983040,-983039,-983040,-1048573,-1048573,-983039,-1179648,-720894,-589823,-1507326,-1245184,-917502,-983040,-1048573,-983038,-983038,-1048574,-1048573,-983038,-983039,-1048573,-1048574,-1048575,-917503,-983039,-917504,-983037,-1048574,-1048576,-983039,-1048575,-1114111,-1048574,-1048575,-1114109,-1048573,-983040,-1048573,-983037,-983039,-1048576,-983040,-983038,-1048573,-1048574,-983037,-1048575,-1048574,-1048575,-1114109,-1114109,-1048574,-1048576,-1114111,-1114109,-983039,-983039,-1114110,-1179645,-1114109,-1114109,-1048573,-1048575,-1048574,-1048575,-1048576,-917503,-1245184,-720893,-131072,-1179645,-1638397,-1048573,-1048576,-1114109,-1114109,-983040,-1114109,-1114111,-983039,-1114112,-1114111,-983039,-1048574,-1114109,-1048576,-1048575,-1114109,-1048573,-1048573,-917502,-983040,-1114109,-1048574,-1048574,-983037,-1048573,-1048576,-1048575,-1048575,-1048573,-1114109,-1048575,-983039,-1048573,-1048576,-1048575,-1048575,-1048574,-1048573,-1048573,-1048574,-983038,-917503,-983039,-983037,-917502,-917504,-983038,-983037,-917504,-1048574,-983037,-1048574,-1048576,-1114110,-1114110,-1114112,-1048574,-1048574,-1048573,-1048573,-196608,-589823,-1507326,-917503,-1048574,-983037,-983040,-1048573,-983039,-983039,-983040,-1048575,-1048574,-1048573,-983040,-1048574,-983038,-851966,-917504,-983040,-983039,-983040,-1048576,-1048573,-983039,-983040,-983037,-983039,-1048573,-1048574,-983039,-917503,-917503,-917503,-983038,-917503,-851968,-917502,-917504,-983037,-983037'

# %%
y=ecg_data.split(',')

# %%
ecg_time='0.004,0.018,0.031,0.045,0.111,0.125,0.138,0.152,0.165,0.179,0.193,0.206,0.220,0.233,0.247,0.260,0.274,0.287,0.301,0.314,0.328,0.341,0.355,0.369,0.382,0.396,0.409,0.423,0.436,0.450,0.463,0.477,0.490,0.504,0.518,0.531,0.545,0.558,0.572,0.585,0.599,0.612,0.626,0.639,0.653,0.666,0.680,0.694,0.707,0.721,0.734,0.748,0.761,0.775,0.788,0.802,0.815,0.829,0.843,0.856,0.870,0.883,0.897,0.910,0.924,0.937,0.951,0.964,0.978,0.991,1.005,1.019,1.032,1.046,1.059,1.073,1.086,1.100,1.113,1.127,1.140,1.154,1.168,1.181,1.195,1.208,1.222,1.235,1.249,1.262,1.276,1.289,1.303,1.316,1.330,1.344,1.357,1.371,1.384,1.398,1.411,1.425,1.438,1.452,1.465,1.479,1.493,1.506,1.520,1.533,1.547,1.560,1.574,1.587,1.601,1.614,1.628,1.641,1.655,1.669,1.682,1.696,1.709,1.723,1.736,1.750,1.763,1.777,1.790,1.804,1.818,1.831,1.898,1.911,1.925,1.938,1.952,1.965,1.979,1.993,2.006,2.020,2.033,2.047,2.060,2.074,2.087,2.101,2.114,2.128,2.141,2.155,2.169,2.182,2.196,2.209,2.223,2.236,2.250,2.263,2.277,2.290,2.304,2.318,2.331,2.345,2.358,2.372,2.385,2.399,2.412,2.426,2.439,2.453,2.466,2.480,2.494,2.507,2.521,2.534,2.548,2.561,2.575,2.588,2.602,2.615,2.629,2.643,2.656,2.670,2.683,2.697,2.710,2.724,2.737,2.751,2.764,2.778,2.791,2.805,2.819,2.832,2.846,2.859,2.873,2.886,2.900,2.913,2.927,2.940,2.954,2.968,2.981,2.995,3.008,3.022,3.035,3.049,3.062,3.076,3.089,3.103,3.116,3.130,3.144,3.157,3.171,3.184,3.198,3.211,3.225,3.238,3.252,3.265,3.279,3.293,3.306,3.320,3.333,3.347,3.360,3.374,3.387,3.401,3.414,3.428,3.441,3.455,3.469,3.482,3.496,3.509,3.523,3.536,3.550,3.563,3.577,3.590,3.604,3.618,3.631,3.645,3.711,3.725,3.738,3.752,3.765,3.779,3.793,3.806,3.820,3.833,3.847,3.860,3.874,3.887,3.901,3.914,3.928,3.941,3.955,3.969,3.982,3.996,4.009,4.023,4.036,4.050,4.063,4.077,4.090,4.104,4.118,4.131,4.145,4.158,4.172,4.185,4.199,4.212,4.226,4.239,4.253,4.266,4.280,4.294,4.307,4.321,4.334,4.348,4.361,4.375,4.388,4.402,4.415,4.429,4.443,4.456,4.470,4.483,4.497,4.510,4.524,4.537,4.551,4.564,4.578,4.591,4.605,4.619,4.632,4.646,4.659,4.673,4.686,4.700,4.713,4.727,4.740,4.754,4.768,4.781,4.795,4.808,4.822,4.835,4.849,4.862,4.876,4.889,4.903,4.916,4.930,4.944,4.957,4.971,4.984,4.998,5.011,5.025,5.038,5.052,5.065,5.079,5.093,5.106,5.120,5.133,5.147,5.160,5.174,5.187,5.201,5.214,5.228,5.241,5.255,5.269,5.282,5.296,5.309,5.323,5.336,5.350,5.363,5.377,5.390,5.404,5.418,5.431,5.445,5.458,5.472,5.485,5.499,5.565,5.579,5.593,5.606,5.620,5.633,5.647,5.660,5.674,5.687,5.701,5.714,5.728,5.741,5.755,5.769,5.782,5.796,5.809,5.823,5.836,5.850,5.863,5.877,5.890,5.904,5.918,5.931,5.945,5.958,5.972,5.985,5.999,6.012,6.026,6.039,6.053,6.066,6.080,6.094,6.107,6.121,6.134,6.148,6.161,6.175,6.188,6.202,6.215,6.229,6.243,6.256,6.270,6.283,6.297,6.310,6.324,6.337,6.351,6.364,6.378,6.391,6.405,6.419,6.432,6.446,6.459,6.473,6.486,6.500,6.513,6.527,6.540,6.554,6.568,6.581,6.595,6.608,6.622,6.635,6.649,6.662,6.676,6.689,6.703,6.716,6.730,6.744,6.757,6.771,6.784,6.798,6.811,6.825,6.838,6.852,6.865,6.879,6.893,6.906,6.920,6.933,6.947,6.960,6.974,6.987,7.001,7.014,7.028,7.041,7.055,7.069,7.082,7.096,7.109,7.123,7.136,7.150,7.163,7.177,7.190,7.204,7.218,7.231,7.245,7.258,7.272,7.285,7.299,7.312,7.326,7.339,7.353,7.366,7.380,7.394,7.407,7.421,7.487,7.501,7.514,7.528,7.541,7.555,7.569,7.582,7.596,7.609,7.623,7.636,7.650,7.663,7.677,7.690,7.704,7.718,7.731,7.745,7.758,7.772,7.785,7.799,7.812,7.826,7.839,7.853,7.866,7.880,7.894,7.907,7.921,7.934,7.948,7.961,7.975,7.988,8.002,8.015,8.029,8.043,8.056,8.070,8.083,8.097,8.110,8.124,8.137,8.151,8.164,8.178,8.191,8.205,8.219,8.232,8.246,8.259,8.273,8.286,8.300,8.313,8.327,8.340,8.354,8.368,8.381,8.395,8.408,8.422,8.435,8.449,8.462,8.476,8.489,8.503,8.516,8.530,8.544,8.557,8.571,8.584,8.598,8.611,8.625,8.638,8.652,8.665,8.679,8.693,8.706,8.720,8.733,8.747,8.760,8.774,8.787,8.801,8.814,8.828,8.841,8.855,8.869,8.882,8.896,8.909,8.923,8.936,8.950,8.963,8.977,8.990,9.004,9.018,9.031,9.045,9.058,9.072,9.085,9.099,9.112,9.126,9.139,9.153,9.166,9.180,9.194,9.207,9.221,9.234,9.248,9.261,9.275,9.288,9.302,9.369,9.382,9.396,9.409,9.423,9.436,9.450,9.463,9.477,9.490,9.504,9.518,9.531,9.545,9.558,9.572,9.585,9.599,9.612,9.626,9.639,9.653,9.666,9.680,9.694,9.707,9.721,9.734,9.748,9.761,9.775,9.788,9.802,9.815,9.829,9.843,9.856,9.870,9.883,9.897,9.910,9.924,9.937,9.951,9.964,9.978,9.991,10.005,10.019,10.032,10.046,10.059,10.073,10.086,10.100,10.113,10.127,10.140,10.154,10.167,10.181,10.195,10.208,10.222,10.235,10.249,10.262,10.276,10.289,10.303,10.316,10.330,10.344,10.357,10.371,10.384,10.398,10.411,10.425,10.438,10.452,10.465,10.479,10.492,10.506,10.520,10.533,10.547,10.560,10.574,10.587,10.601,10.614,10.628,10.641,10.655,10.669,10.682,10.696,10.709,10.723,10.736,10.750,10.764,10.779,10.792,10.806,10.820,10.833,10.847,10.860,10.874,10.887,10.901,10.914,10.928,10.941,10.955,10.969,10.982,10.996,11.009,11.023,11.036,11.050,11.063,11.077,11.090,11.104,11.117,11.131,11.145,11.158,11.172,11.185,11.199,11.212,11.226,11.292,11.306,11.320,11.333,11.347,11.360,11.374,11.387,11.401,11.414,11.428,11.441,11.455,11.469,11.482,11.496,11.509,11.523,11.536,11.550,11.563,11.577,11.590,11.604,11.617,11.631,11.645,11.658,11.672,11.685,11.699,11.712,11.726,11.739,11.753,11.766,11.780,11.794,11.807,11.821,11.834,11.848,11.861,11.875,11.888,11.902,11.915,11.929,11.942,11.956,11.970,11.983,11.997,12.010,12.024,12.037,12.051,12.064,12.078,12.091,12.105,12.119,12.132,12.146,12.159,12.173,12.186,12.200,12.213,12.227,12.240,12.254,12.267,12.281,12.295,12.308,12.322,12.335,12.349,12.362,12.376,12.389,12.403,12.416,12.430,12.444,12.457,12.471,12.484,12.498,12.511,12.525,12.538,12.552,12.565,12.579,12.592,12.606,12.620,12.634,12.648,12.661,12.675,12.688,12.702,12.715,12.729,12.742,12.756,12.770,12.783,12.797,12.810,12.824,12.837,12.851,12.864,12.878,12.891,12.905,12.919,12.932,12.946,12.959,12.973,12.986,13.000,13.013,13.080,13.094,13.107,13.121,13.134,13.148,13.161,13.175,13.188,13.202,13.215,13.229,13.242,13.256,13.270,13.283,13.297,13.310,13.324,13.337,13.351,13.364,13.378,13.391,13.405,13.419,13.432,13.446,13.459,13.473,13.486,13.500,13.513,13.527,13.540,13.554,13.567,13.581,13.595,13.608,13.622,13.635,13.649,13.662,13.676,13.689,13.703,13.716,13.730,13.744,13.757,13.771,13.784,13.798,13.811,13.825,13.838,13.852,13.865,13.879,13.892,13.906,13.920,13.933,13.947,13.960,13.974,13.987,14.001,14.014,14.028,14.041,14.055,14.069,14.082,14.096,14.109,14.123,14.136,14.150,14.163,14.177,14.190,14.204,14.217,14.231,14.245,14.258,14.272,14.285,14.299,14.312,14.326,14.339,14.353,14.366,14.380,14.394,14.407,14.421,14.434,14.448,14.461,14.475,14.488,14.502,14.515,14.529,14.542,14.556,14.570,14.583,14.597,14.610,14.624,14.637,14.651,14.664,14.678,14.691,14.705,14.719,14.732,14.746,14.759,14.773,14.786,14.800,14.813,14.827,14.840,14.854,14.867,14.934,14.948,14.961,14.975,14.988,15.002,15.015,15.029,15.042,15.056,15.070,15.083,15.097,15.110,15.124,15.137,15.151,15.164,15.178,15.191,15.205,15.219,15.232,15.246,15.259,15.273,15.286,15.300,15.313,15.327,15.340,15.354,15.367,15.381,15.395,15.408,15.422,15.435,15.449,15.462,15.476,15.489,15.503,15.516,15.530,15.544,15.557,15.571,15.584,15.598,15.611,15.625,15.638,15.652,15.665,15.679,15.692,15.706,15.720,15.733,15.747,15.760,15.774,15.787,15.801,15.814,15.828,15.841,15.855,15.869,15.882,15.896,15.909,15.923,15.936,15.950,15.963,15.977,15.990,16.004,16.017,16.031,16.045,16.058,16.072,16.085,16.099,16.112,16.126,16.139,16.153,16.166,16.180,16.194,16.207,16.221,16.234,16.248,16.261,16.275,16.288,16.302,16.315,16.329,16.342,16.356,16.370,16.383,16.397,16.410,16.424,16.437,16.451,16.464,16.478,16.491,16.505,16.519,16.532,16.546,16.559,16.573,16.586,16.600,16.613,16.627,16.640,16.654,16.721,16.734,16.748,16.761,16.775,16.788,16.802,16.815,16.829,16.842,16.856,16.870,16.883,16.897,16.910,16.924,16.937,16.951,16.964,16.978,16.991,17.005,17.019,17.032,17.046,17.059,17.073,17.086,17.100,17.113,17.127,17.140,17.154,17.167,17.181,17.195,17.208,17.222,17.235,17.249,17.262,17.276,17.289,17.303,17.316,17.330,17.344,17.357,17.371,17.384,17.398,17.411,17.425,17.438,17.452,17.465,17.479,17.492,17.506,17.520,17.533,17.547,17.560,17.574,17.587,17.601,17.614,17.628,17.641,17.655,17.669,17.682,17.696,17.709,17.723,17.736,17.750,17.763,17.777,17.790,17.804,17.817,17.831,17.845,17.858,17.872,17.885,17.899,17.912,17.926,17.939,17.953,17.966,17.980,17.994,18.007,18.021,18.034,18.048,18.061,18.075,18.088,18.102,18.115,18.129,18.142,18.156,18.170,18.183,18.197,18.210,18.224,18.237,18.251,18.264,18.278,18.291,18.305,18.319,18.332,18.346,18.359,18.373,18.386,18.400,18.413,18.427,18.440,18.454,18.467,18.481,18.495,18.508,18.522,18.535,18.549,18.562,18.576,18.589,18.603,18.671,18.684,18.698,18.711,18.725,18.738,18.752,18.765,18.779,18.792,18.806,18.820,18.833,18.847,18.860,18.874,18.887,18.901,18.914,18.928,18.941,18.955,18.969,18.982,18.996,19.009,19.023,19.036,19.050,19.063,19.077,19.090,19.104,19.117,19.131,19.145,19.158,19.172,19.185,19.199,19.212,19.226,19.239,19.253,19.266,19.280,19.294,19.307,19.321,19.334,19.348,19.361,19.375,19.388,19.402,19.415,19.429,19.442,19.456,19.470,19.483,19.497,19.510,19.524,19.537,19.551,19.564,19.578,19.591,19.605,19.619,19.632,19.646,19.659,19.673,19.686,19.700,19.713,19.727,19.740,19.754,19.767,19.781,19.795,19.808,19.822,19.835,19.849,19.862,19.876,19.889,19.903,19.916,19.930,19.944,19.957,19.971,19.984,19.998,20.011,20.025,20.038,20.052,20.065,20.079,20.092,20.106,20.120,20.133,20.147,20.160,20.174,20.187,20.201,20.214,20.228,20.241,20.255,20.269,20.282,20.296,20.309,20.323,20.336,20.350,20.363,20.377,20.390,20.404,20.417,20.431,20.445,20.458,20.525,20.538,20.552,20.565,20.579,20.592,20.606,20.620,20.633,20.647,20.660,20.674,20.687,20.701,20.714,20.728,20.742,20.756,20.770,20.783,20.797,20.810,20.824,20.837,20.851,20.864,20.878,20.891,20.905,20.919,20.932,20.946,20.959,20.973,20.986,21.000,21.013,21.027,21.040,21.054,21.067,21.081,21.095,21.108,21.122,21.135,21.149,21.162,21.176,21.189,21.203,21.216,21.230,21.244,21.257,21.271,21.284,21.298,21.311,21.325,21.338,21.352,21.365,21.379,21.392,21.406,21.420,21.433,21.447,21.460,21.474,21.487,21.501,21.514,21.528,21.541,21.555,21.569,21.582,21.596,21.609,21.623,21.636,21.650,21.663,21.677,21.690,21.704,21.717,21.731,21.745,21.758,21.772,21.785,21.799,21.812,21.826,21.839,21.853,21.866,21.880,21.894,21.907,21.921,21.934,21.948,21.961,21.975,21.988,22.002,22.015,22.029,22.042,22.056,22.070,22.083,22.097,22.110,22.124,22.137,22.151,22.164,22.178,22.191,22.205,22.219,22.232,22.246,22.259,22.326,22.339,22.353,22.366,22.380,22.394,22.407,22.421,22.434,22.448,22.461,22.475,22.488,22.502,22.515,22.529,22.542,22.556,22.570,22.583,22.597,22.610,22.624,22.637,22.651,22.664,22.678,22.691,22.705,22.719,22.732,22.746,22.759,22.773,22.786,22.800,22.813,22.827,22.840,22.854,22.867,22.881,22.895,22.908,22.922,22.935,22.949,22.962,22.976,22.989,23.003,23.016,23.030,23.044,23.057,23.071,23.084,23.098,23.111,23.125,23.138,23.152,23.165,23.179,23.192,23.206,23.220,23.233,23.247,23.260,23.274,23.287,23.301,23.314,23.328,23.341,23.355,23.369,23.382,23.396,23.409,23.423,23.436,23.450,23.463,23.477,23.490,23.504,23.517,23.531,23.545,23.558,23.572,23.585,23.599,23.612,23.626,23.639,23.653,23.666,23.680,23.694,23.707,23.721,23.734,23.748,23.761,23.775,23.788,23.802,23.815,23.829,23.842,23.856,23.870,23.883,23.897,23.910,23.924,23.937,23.951,23.964,23.978,23.991,24.005,24.019,24.032,24.046,24.059,24.073,24.086,24.100,24.166,24.180,24.194,24.207,24.221,24.234,24.248,24.261,24.275,24.288,24.302,24.315,24.329,24.342,24.356,24.370,24.383,24.397,24.410,24.424,24.437,24.451,24.464,24.478,24.491,24.505,24.519,24.532,24.546,24.559,24.573,24.586,24.600,24.613,24.627,24.640,24.654,24.667,24.681,24.695,24.708,24.722,24.735,24.749,24.762,24.776,24.789,24.803,24.816,24.830,24.844,24.857,24.871,24.884,24.898,24.911,24.925,24.938,24.952,24.965,24.979,24.992,25.006,25.020,25.033,25.047,25.060,25.074,25.087,25.101,25.114,25.128,25.141,25.155,25.169,25.182,25.196,25.209,25.223,25.236,25.250,25.263,25.277,25.290,25.304,25.317,25.331,25.345,25.358,25.372,25.385,25.399,25.412,25.426,25.439,25.453,25.466,25.480,25.494,25.507,25.521,25.534,25.548,25.561,25.575,25.588,25.602,25.615,25.629,25.642,25.656,25.670,25.683,25.697,25.710,25.724,25.737,25.751,25.764,25.778,25.791,25.805,25.819,25.832,25.846,25.859,25.873,25.886,25.900,25.913,25.927,25.940,25.954,25.967,25.981,25.995,26.008,26.022,26.035,26.049,26.115,26.129,26.142,26.156,26.170,26.183,26.197,26.210,26.224,26.237,26.251,26.264,26.278,26.291,26.305,26.319,26.332,26.346,26.359,26.373,26.386,26.400,26.413,26.427,26.440,26.454,26.467,26.481,26.495,26.508,26.522,26.535,26.549,26.562,26.576,26.589,26.603,26.616,26.630,26.644,26.657,26.671,26.684,26.698,26.711,26.725,26.738,26.752,26.765,26.779,26.792,26.806,26.820,26.833,26.847,26.860,26.874,26.887,26.901,26.914,26.928,26.941,26.955,26.968,26.982,26.996,27.009,27.023,27.036,27.050,27.063,27.077,27.090,27.104,27.117,27.131,27.145,27.158,27.172,27.185,27.199,27.212,27.226,27.239,27.253,27.266,27.280,27.293,27.307,27.321,27.334,27.348,27.361,27.375,27.388,27.402,27.415,27.429,27.442,27.456,27.470,27.483,27.497,27.510,27.524,27.537,27.551,27.564,27.578,27.591,27.605,27.618,27.632,27.646,27.659,27.673,27.686,27.700,27.713,27.727,27.740,27.754,27.767,27.781,27.795,27.808,27.822,27.835,27.849,27.862,27.876,27.889,27.903,27.916,27.930,27.943,27.957,27.971,27.984,27.998,28.011,28.025,28.038,28.052,28.065,28.079,28.092,28.106,28.120,28.133,28.147,28.160,28.174,28.187,28.201,28.214,28.228,28.241,28.255,28.268,28.282,28.296,28.309,28.323,28.336,28.350,28.363,28.377,28.390,28.404,28.417,28.431,28.445,28.458,28.472,28.485,28.499,28.512,28.526,28.539,28.553,28.566,28.580,28.593,28.607,28.621,28.634,28.648,28.661,28.675,28.688,28.702,28.715,28.729,28.742,28.756,28.770,28.783,28.797,28.810,28.824,28.837,28.851,28.864,28.878,28.891,28.905,28.980,28.993,29.007,29.021,29.034,29.048,29.061,29.075,29.088,29.102,29.115,29.129,29.142,29.156,29.170,29.183,29.197,29.210,29.224,29.237,29.251,29.264,29.278,29.291,29.305,29.318,29.332,29.346,29.359,29.373,29.386,29.400,29.413,29.427,29.440,29.454,29.467,29.481,29.495,29.508,29.522,29.535,29.549,29.562,29.576,29.589,29.603,29.616,29.630,29.643,29.657,29.671,29.684,29.698,29.711,29.725,29.738,29.752,29.765,29.779,29.792,29.806,29.820,29.833,29.847,29.860,29.874,29.887,29.901,29.914,29.928,29.941,29.955,29.968,29.982,29.996,30.009,30.023,30.036,30.050,30.063,30.077,30.090,30.104,30.117,30.131,30.145,30.158,30.172,30.185,30.199,30.212,30.226,30.239,30.253,30.266,30.280,30.293,30.307,30.321,30.334,30.348,30.361,30.375,30.388,30.402,30.415,30.429,30.442,30.456,30.470,30.483,30.497,30.510,30.524,30.537,30.551,30.564,30.578,30.591,30.605,30.618,30.632,30.646,30.659,30.673,30.686,30.700,30.713,30.727,30.740,30.754,30.767,30.781,30.795,30.861,30.875,30.888,30.902,30.915,30.929,30.942,30.956,30.970,30.983,30.997,31.010,31.024,31.037,31.051,31.064,31.078,31.091,31.105,31.118,31.132,31.146,31.159,31.173,31.186,31.200,31.213,31.227,31.240,31.254,31.267,31.281,31.295,31.308,31.322,31.335,31.349,31.362,31.376,31.389,31.403,31.416,31.430,31.443,31.457,31.471,31.484,31.498,31.511,31.525,31.538,31.552,31.565,31.579,31.592,31.606,31.620,31.633,31.647,31.660,31.674,31.687,31.701,31.714,31.728,31.741,31.755,31.768,31.782,31.796,31.809,31.823,31.836,31.850,31.863,31.877,31.890,31.904,31.917,31.931,31.945,31.958,31.972,31.985,31.999,32.012,32.026,32.039,32.053,32.066,32.080,32.093,32.107,32.121,32.134,32.148,32.161,32.175,32.188,32.202,32.215,32.229,32.242,32.256,32.270,32.283,32.297,32.310,32.324,32.337,32.351,32.364,32.378,32.391,32.405,32.418,32.432,32.446,32.459,32.473,32.486,32.500,32.513,32.527,32.540,32.554,32.567,32.581,32.595,32.608,32.622,32.635,32.649,32.662,32.676,32.689,32.703,32.716,32.730,32.743,32.757,32.824,32.837,32.851,32.864,32.878,32.891,32.905,32.918,32.932,32.946,32.959,32.973,32.986,33.000,33.013,33.027,33.040,33.054,33.067,33.081,33.095,33.108,33.122,33.135,33.149,33.162,33.176,33.189,33.203,33.216,33.230,33.243,33.257,33.271,33.284,33.298,33.311,33.325,33.338,33.352,33.365,33.379,33.392,33.406,33.420,33.433,33.447,33.460,33.474,33.487,33.501,33.514,33.528,33.541,33.555,33.568,33.582,33.596,33.609,33.623,33.636,33.650,33.663,33.677,33.690,33.704,33.717,33.731,33.745,33.758,33.772,33.785,33.799,33.812,33.826,33.839,33.853,33.866,33.880,33.893,33.907,33.921,33.934,33.948,33.961,33.975,33.988,34.002,34.015,34.029,34.042,34.056,34.070,34.083,34.097,34.110,34.124,34.137,34.151,34.164,34.178,34.191,34.205,34.218,34.232,34.246,34.259,34.273,34.286,34.300,34.313,34.327,34.340,34.354,34.367,34.381,34.395,34.408,34.422,34.435,34.449,34.462,34.476,34.489,34.503,34.516,34.530,34.543,34.557,34.571,34.584,34.598,34.611,34.625,34.638,34.652,34.665,34.679,34.692,34.706,34.781,34.795,34.808,34.822,34.835,34.849,34.862,34.876,34.889,34.903,34.916,34.930,34.943,34.957,34.971,34.984,34.998,35.011,35.025,35.038,35.052,35.065,35.079,35.092,35.106,35.120,35.133,35.147,35.160,35.174,35.187,35.201,35.214,35.228,35.241,35.255,35.268,35.282,35.296,35.309,35.323,35.336,35.350,35.363,35.377,35.390,35.404,35.417,35.431,35.445,35.458,35.472,35.485,35.499,35.512,35.526,35.539,35.553,35.566,35.580,35.593,35.607,35.621,35.634,35.648,35.661,35.675,35.688,35.702,35.715,35.729,35.742,35.756,35.770,35.783,35.797,35.810,35.824,35.837,35.851,35.864,35.878,35.891,35.905,35.918,35.932,35.946,35.959,35.973,35.986,36.000,36.013,36.027,36.040,36.054,36.067,36.081,36.095,36.108,36.122,36.135,36.149,36.162,36.176,36.189,36.203,36.216,36.230,36.243,36.257,36.271,36.284,36.298,36.311,36.325,36.338,36.352,36.365,36.379,36.392,36.406,36.420,36.433,36.447,36.460,36.474,36.487,36.501,36.514,36.528,36.541,36.555,36.568,36.582,36.596,36.609,36.623,36.636,36.650,36.716,36.730,36.743,36.757,36.771,36.784,36.798,36.811,36.825,36.838,36.852,36.865,36.879,36.892,36.906,36.920,36.934,36.949,36.962,36.976,36.989,37.003,37.016,37.030,37.043,37.057,37.071,37.084,37.098,37.111,37.125,37.138,37.152,37.165,37.179,37.192,37.206,37.220,37.233,37.247,37.260,37.274,37.287,37.301,37.314,37.328,37.341,37.355,37.368,37.382,37.396,37.409,37.423,37.436,37.450,37.463,37.477,37.490,37.504,37.517,37.531,37.545,37.558,37.572,37.585,37.599,37.612,37.626,37.639,37.653,37.666,37.680,37.693,37.707,37.721,37.734,37.748,37.761,37.775,37.788,37.802,37.815,37.829,37.842,37.856,37.870,37.883,37.897,37.910,37.924,37.937,37.951,37.964,37.978,37.991,38.005,38.018,38.032,38.046,38.059,38.073,38.086,38.100,38.113,38.127,38.140,38.154,38.167,38.181,38.195,38.208,38.222,38.235,38.249,38.262,38.276,38.289,38.303,38.316,38.330,38.343,38.357,38.371,38.384,38.398,38.411,38.425,38.438,38.452,38.465,38.479,38.492,38.506,38.520,38.533,38.547,38.560,38.574,38.587,38.601,38.614,38.628,38.695,38.708,38.722,38.735,38.749,38.762,38.776,38.789,38.803,38.816,38.830,38.843,38.857,38.871,38.884,38.898,38.911,38.925,38.938,38.952,38.965,38.979,38.992,39.006,39.020,39.033,39.047,39.060,39.074,39.087,39.101,39.114,39.128,39.141,39.155,39.168,39.182,39.196,39.209,39.223,39.236,39.250,39.263,39.277,39.290,39.304,39.317,39.331,39.345,39.358,39.372,39.385,39.399,39.412,39.426,39.439,39.453,39.466,39.480,39.493,39.507,39.521,39.534,39.548,39.561,39.575,39.588,39.602,39.615,39.629,39.642,39.656,39.670,39.683,39.697,39.710,39.724,39.737,39.751,39.764,39.778,39.791,39.805,39.818,39.832,39.846,39.859,39.873,39.886,39.900,39.913,39.927,39.940,39.954,39.967,39.981,39.995,40.008,40.022,40.035,40.049,40.062,40.076,40.089,40.103,40.116,40.130,40.143,40.157,40.171,40.184,40.198,40.211,40.225,40.238,40.252,40.265,40.279,40.292,40.306,40.320,40.333,40.347,40.360,40.374,40.387,40.401,40.414,40.428,40.441,40.455,40.468,40.482,40.496,40.509,40.523,40.589,40.603,40.616,40.630,40.643,40.657,40.671,40.684,40.698,40.711,40.725,40.738,40.752,40.765,40.779,40.792,40.806,40.820,40.833,40.847,40.860,40.874,40.887,40.901,40.914,40.928,40.941,40.955,40.968,40.982,40.996,41.009,41.023,41.036,41.050,41.063,41.077,41.090,41.104,41.117,41.131,41.145,41.158,41.172,41.185,41.199,41.212,41.226,41.239,41.253,41.266,41.280,41.293,41.307,41.321,41.334,41.348,41.361,41.375,41.388,41.402,41.415,41.429,41.442,41.456,41.470,41.483,41.497,41.510,41.524,41.537,41.551,41.564,41.578,41.591,41.605,41.618,41.632,41.646,41.659,41.673,41.686,41.700,41.713,41.727,41.740,41.754,41.767,41.781,41.795,41.808,41.822,41.835,41.849,41.862,41.876,41.889,41.903,41.916,41.930,41.943,41.957,41.971,41.984,41.998,42.011,42.025,42.038,42.052,42.065,42.079,42.092,42.106,42.120,42.133,42.147,42.160,42.174,42.187,42.201,42.214,42.228,42.241,42.255,42.268,42.282,42.296,42.309,42.323,42.336,42.350,42.363,42.377,42.390,42.404,42.417,42.431,42.445,42.458,42.525,42.538,42.552,42.565,42.579,42.592,42.606,42.620,42.633,42.647,42.660,42.674,42.687,42.701,42.714,42.728,42.741,42.755,42.768,42.782,42.796,42.809,42.823,42.836,42.850,42.863,42.877,42.890,42.904,42.917,42.931,42.944,42.958,42.972,42.985,42.999,43.012,43.026,43.039,43.053,43.066,43.080,43.093,43.107,43.121,43.134,43.148,43.161,43.175,43.188,43.202,43.215,43.229,43.242,43.256,43.269,43.283,43.297,43.310,43.324,43.337,43.351,43.364,43.378,43.391,43.405,43.418,43.432,43.446,43.459,43.473,43.486,43.500,43.513,43.527,43.540,43.554,43.567,43.581,43.594,43.608,43.622,43.635,43.650,43.663,43.677,43.690,43.704,43.717,43.731,43.744,43.758,43.772,43.785,43.799,43.812,43.826,43.839,43.853,43.866,43.880,43.893,43.907,43.921,43.934,43.948,43.961,43.975,43.988,44.002,44.015,44.029,44.042,44.056,44.069,44.083,44.097,44.110,44.124,44.137,44.151,44.164,44.178,44.191,44.205,44.218,44.232,44.246,44.259,44.273,44.286,44.300,44.366,44.380,44.393,44.407,44.421,44.434,44.448,44.461,44.475,44.488,44.502,44.515,44.529,44.542,44.556,44.569,44.583,44.597,44.610,44.624,44.637,44.651,44.664,44.678,44.691,44.705,44.718,44.732,44.746,44.759,44.773,44.786,44.800,44.813,44.827,44.840,44.854,44.867,44.881,44.894,44.908,44.922,44.935,44.949,44.962,44.976,44.989,45.003,45.016,45.030,45.043,45.057,45.071,45.084,45.098,45.111,45.125,45.138,45.152,45.165,45.179,45.192,45.206,45.219,45.233,45.247,45.260,45.274,45.287,45.301,45.314,45.328,45.341,45.355,45.368,45.382,45.396,45.409,45.423,45.436,45.450,45.463,45.477,45.490,45.504,45.517,45.531,45.544,45.558,45.572,45.585,45.599,45.612,45.626,45.639,45.653,45.666,45.680,45.693,45.707,45.721,45.734,45.748,45.761,45.775,45.788,45.802,45.815,45.829,45.842,45.856,45.869,45.883,45.897,45.910,45.924,45.937,45.951,45.964,45.978,45.991,46.005,46.018,46.032,46.046,46.059,46.073,46.086,46.100,46.113,46.127,46.193,46.207,46.221,46.234,46.248,46.261,46.275,46.288,46.302,46.315,46.329,46.342,46.356,46.369,46.383,46.397,46.410,46.424,46.437,46.451,46.464,46.478,46.491,46.505,46.518,46.532,46.546,46.559,46.573,46.586,46.600,46.613,46.627,46.640,46.654,46.667,46.681,46.694,46.708,46.722,46.735,46.749,46.762,46.776,46.789,46.803,46.816,46.830,46.843,46.857,46.871,46.884,46.898,46.911,46.925,46.938,46.952,46.965,46.979,46.992,47.006,47.019,47.033,47.047,47.060,47.074,47.087,47.101,47.114,47.128,47.141,47.155,47.168,47.182,47.196,47.209,47.223,47.236,47.250,47.263,47.277,47.290,47.304,47.317,47.331,47.344,47.358,47.372,47.385,47.399,47.412,47.426,47.439,47.453,47.466,47.480,47.493,47.507,47.521,47.534,47.548,47.561,47.575,47.588,47.602,47.615,47.629,47.642,47.656,47.669,47.683,47.697,47.710,47.724,47.737,47.751,47.764,47.778,47.791,47.805,47.818,47.832,47.846,47.859,47.873,47.886,47.900,47.913,47.927,47.940,47.954,47.967,47.981,47.994,48.008,48.075,48.088,48.102,48.115,48.129,48.142,48.156,48.169,48.183,48.197,48.210,48.224,48.237,48.251,48.264,48.278,48.291,48.305,48.318,48.332,48.346,48.359,48.373,48.386,48.400,48.413,48.427,48.440,48.454,48.467,48.481,48.494,48.508,48.522,48.535,48.549,48.562,48.576,48.589,48.603,48.616,48.630,48.643,48.657,48.671,48.684,48.698,48.711,48.725,48.738,48.752,48.765,48.779,48.792,48.806,48.819,48.833,48.847,48.860,48.874,48.887,48.901,48.914,48.928,48.941,48.955,48.968,48.982,48.996,49.009,49.023,49.036,49.050,49.063,49.077,49.090,49.104,49.117,49.131,49.144,49.158,49.172,49.185,49.199,49.212,49.226,49.239,49.253,49.266,49.280,49.293,49.307,49.321,49.334,49.348,49.361,49.375,49.388,49.402,49.415,49.429,49.442,49.456,49.469,49.483,49.497,49.510,49.524,49.537,49.551,49.564,49.578,49.591,49.605,49.618,49.632,49.646,49.659,49.673,49.686,49.700,49.713,49.727,49.740,49.754,49.767,49.781,49.794,49.808,49.822,49.835,49.849,49.862,49.876,49.889,49.903,49.969,49.983,49.997,50.010,50.024,50.037,50.051,50.064,50.078,50.091,50.105,50.118,50.132,50.146,50.159,50.173,50.186,50.200,50.213,50.227,50.240,50.254,50.267,50.281,50.294,50.308,50.322,50.335,50.349,50.362,50.376,50.389,50.403,50.416,50.430,50.443,50.457,50.471,50.484,50.498,50.511,50.525,50.538,50.552,50.565,50.579,50.592,50.606,50.619,50.633,50.647,50.660,50.674,50.687,50.701,50.714,50.728,50.741,50.755,50.768,50.782,50.796,50.809,50.823,50.836,50.850,50.863,50.877,50.890,50.904,50.917,50.931,50.944,50.958,50.972,50.985,50.999,51.012,51.026,51.039,51.053,51.066,51.080,51.093,51.107,51.121,51.134,51.148,51.161,51.175,51.188,51.202,51.215,51.229,51.242,51.256,51.269,51.283,51.297,51.310,51.324,51.337,51.351,51.364,51.378,51.391,51.405,51.418,51.432,51.446,51.459,51.473,51.486,51.500,51.513,51.527,51.540,51.554,51.567,51.581,51.594,51.608,51.622,51.635,51.649,51.662,51.676,51.689,51.703,51.716,51.730,51.743,51.757,51.771,51.784,51.798,51.811,51.878,51.891,51.905,51.918,51.932,51.946,51.959,51.973,51.986,52.000,52.013,52.027,52.040,52.054,52.067,52.081,52.094,52.108,52.122,52.135,52.149,52.162,52.176,52.189,52.203,52.216,52.230,52.243,52.257,52.271,52.284,52.298,52.311,52.325,52.338,52.352,52.365,52.379,52.392,52.406,52.419,52.433,52.447,52.460,52.474,52.487,52.501,52.514,52.528,52.541,52.555,52.568,52.582,52.596,52.609,52.623,52.636,52.650,52.663,52.677,52.690,52.704,52.717,52.731,52.744,52.758,52.772,52.785,52.799,52.812,52.826,52.839,52.853,52.866,52.880,52.893,52.907,52.921,52.934,52.948,52.961,52.975,52.988,53.002,53.015,53.029,53.042,53.056,53.069,53.083,53.097,53.110,53.124,53.137,53.151,53.164,53.178,53.191,53.205,53.218,53.232,53.246,53.259,53.273,53.286,53.300,53.313,53.327,53.340,53.354,53.367,53.381,53.394,53.408,53.422,53.435,53.449,53.462,53.476,53.489,53.503,53.516,53.530,53.543,53.557,53.571,53.584,53.598,53.611,53.625,53.638,53.652,53.665,53.679,53.692,53.706,53.773,53.786,53.800,53.813,53.827,53.840,53.854,53.867,53.881,53.894,53.908,53.922,53.935,53.949,53.962,53.976,53.989,54.003,54.016,54.030,54.043,54.057,54.071,54.084,54.098,54.111,54.125,54.138,54.152,54.165,54.179,54.192,54.206,54.219,54.233,54.247,54.260,54.274,54.287,54.301,54.314,54.328,54.341,54.355,54.368,54.382,54.396,54.409,54.423,54.436,54.450,54.463,54.477,54.490,54.504,54.517,54.531,54.544,54.558,54.572,54.585,54.599,54.612,54.626,54.639,54.653,54.666,54.680,54.693,54.707,54.721,54.734,54.748,54.761,54.775,54.788,54.802,54.815,54.829,54.842,54.856,54.869,54.883,54.897,54.910,54.924,54.937,54.951,54.964,54.978,54.991,55.005,55.018,55.032,55.046,55.059,55.073,55.086,55.100,55.113,55.127,55.140,55.154,55.167,55.181,55.194,55.208,55.222,55.235,55.249,55.262,55.276,55.289,55.303,55.316,55.330,55.343,55.357,55.371,55.384,55.398,55.411,55.425,55.438,55.452,55.465,55.479,55.492,55.506,55.519,55.533,55.547,55.560,55.627,55.640,55.654,55.667,55.681,55.694,55.708,55.722,55.735,55.749,55.762,55.776,55.789,55.803,55.816,55.830,55.843,55.857,55.871,55.884,55.898,55.911,55.925,55.938,55.952,55.965,55.979,55.992,56.006,56.019,56.033,56.047,56.060,56.074,56.087,56.101,56.114,56.128,56.141,56.155,56.168,56.182,56.196,56.209,56.223,56.236,56.250,56.263,56.277,56.290,56.304,56.317,56.331,56.344,56.358,56.372,56.385,56.399,56.412,56.426,56.439,56.453,56.466,56.480,56.493,56.507,56.521,56.534,56.548,56.561,56.575,56.588,56.602,56.615,56.629,56.642,56.656,56.669,56.683,56.697,56.710,56.724,56.737,56.751,56.764,56.778,56.791,56.805,56.818,56.832,56.846,56.859,56.873,56.886,56.900,56.913,56.927,56.940,56.954,56.967,56.981,56.994,57.008,57.022,57.035,57.049,57.062,57.076,57.089,57.103,57.116,57.130,57.143,57.157,57.171,57.184,57.198,57.211,57.225,57.238,57.252,57.265,57.279,57.292,57.306,57.319,57.333,57.347,57.360,57.374,57.387,57.401,57.414,57.428,57.494,57.508,57.522,57.535,57.549,57.562,57.576,57.589,57.603,57.616,57.630,57.643,57.657,57.671,57.684,57.698,57.711,57.725,57.738,57.752,57.765,57.779,57.792,57.806,57.819,57.833,57.847,57.860,57.874,57.887,57.901,57.914,57.928,57.941,57.955,57.968,57.982,57.996,58.009,58.023,58.036,58.050,58.063,58.077,58.090,58.104,58.117,58.131,58.144,58.158,58.172,58.185,58.199,58.212,58.226,58.239,58.253,58.266,58.280,58.293,58.307,58.321,58.334,58.348,58.361,58.375,58.388,58.402,58.415,58.429,58.442,58.456,58.469,58.483,58.497,58.510,58.524,58.537,58.551,58.564,58.578,58.591,58.605,58.618,58.632,58.646,58.659,58.673,58.686,58.700,58.713,58.727,58.740,58.754,58.767,58.781,58.794,58.808,58.822,58.835,58.849,58.862,58.876,58.889,58.903,58.916,58.930,58.943,58.957,58.971,58.984,58.998,59.011,59.025,59.038,59.052,59.065,59.079,59.092,59.106,59.119,59.133,59.147,59.213,59.227,59.240,59.254,59.267,59.281,59.294,59.308,59.322,59.335,59.349,59.362,59.376,59.389,59.403,59.416,59.430,59.443,59.457,59.471,59.484,59.498,59.511,59.525,59.538,59.552,59.565,59.579,59.592,59.606,59.619,59.633,59.647,59.660,59.674,59.687,59.701,59.714,59.728,59.741,59.755,59.768,59.782,59.795,59.809,59.823,59.836,59.850,59.863,59.877,59.890,59.904,59.917,59.931,59.944,59.958,59.972,59.985,59.999'

# %%
x=ecg_time.split(',')

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np

# %%
import array as arr

# %%
len(x)
# Out:
# 4304

# %%
len(y)
# Out:
# 4304

# %%
x1 = arr.array('f',[])

# %%
x2 = arr.array('f',[])

# %%
y1 = arr.array('f',[])

# %%
y2 = arr.array('f',[])

# %%
for i in range(4304):
    x1.append(float(x[i]))

# %%
for i in range(100):
    x2.append(float(x[i]))

# %%
for i in range(4304):
    y1.append(float(y[i]))

# %%
for i in range(100):
    y2.append(float(y[i]))

# %%
plt.rcParams['figure.figsize']=(30,10)

# %%
plt.plot(x1,y1)

# %%
plt.plot(x2,y2)

# %%
rr_time=arr.array('f',[])

# %%
for i in range(4304):
    if y1[i]>-0.75*10**6:
        rr_time.append(float(x1[i]))

# %%
len(rr_time)
# Out:
# 182

# %%
rr_interval = arr.array('f',[])

# %%
for i in range (181):
    rr_interval.append(float(rr_time[i+1]-rr_time[i]))

# %%
plt.plot(rr_interval)

# %%
rr_interval_small=rr_interval[0:30]

# %%
plt.plot(rr_interval_small)

# %%
# discrete Fourier transformed points were calculated and plotted
f=np.zeros(4304)
n=np.arange(4304)
for k in range (4304):
    f[k]=np.sum(y1*np.exp(-2j*np.pi*k*n/4304))
    
plt.plot(abs(f),'g',label='magnitude')
# Out:
# C:\Users\Fakir\AppData\Local\Temp/ipykernel_14304/338636639.py:5: ComplexWarning: Casting complex values to real discards the imaginary part
#   f[k]=np.sum(y1*np.exp(-2j*np.pi*k*n/4304))

# %%
f2=np.zeros(100)
n2=np.arange(100)
for l in range (100):
    f2[l]=np.sum(y2*np.exp(-2j*np.pi*l*n2/100))
    
plt.plot(abs(f2),'g',label='magnitude')
# Out:
# C:\Users\Fakir\AppData\Local\Temp/ipykernel_14304/343691595.py:4: ComplexWarning: Casting complex values to real discards the imaginary part
#   f2[l]=np.sum(y2*np.exp(-2j*np.pi*l*n2/100))

# %%
from scipy import signal

# %%
s1, Pxx_den1 = signal.welch(y1,fs=4304/60, nperseg=256,noverlap=256//2)

plt.semilogy(s1, Pxx_den1)

plt.xlabel('frequency [Hz]')

plt.ylabel('PSD [V**2/Hz]')

plt.show()

# %%
s, Pxx_den = signal.welch(y1,fs=1, nperseg=256,noverlap=256//2)

plt.semilogy(s, Pxx_den)

plt.xlabel('frequency [Hz]')

plt.ylabel('PSD [V**2/Hz]')

plt.show()

# %%
pxx_den = arr.array('f',[])

# %%
for i in range(129):
    pxx_den.append(float(np.log(Pxx_den[i])))

# %%
plt.plot(s,pxx_den)

# %%
Pxx_den
# Out:
# array([3.1499768e+10, 2.9078572e+11, 2.6028209e+11, 1.6268722e+11,
#        1.0636805e+11, 8.4993548e+10, 5.6651416e+10, 7.5833631e+10,
#        8.5418459e+10, 1.0279215e+11, 6.9295333e+10, 5.5487885e+10,
#        3.9216325e+10, 4.7158202e+10, 1.0428617e+11, 1.7799455e+11,
#        1.6379486e+11, 1.5266577e+11, 1.1332294e+11, 5.8891899e+10,
#        3.9312716e+10, 3.2884967e+10, 4.5202145e+10, 5.3105623e+10,
#        3.4224321e+10, 2.6281800e+10, 3.1632669e+10, 2.5647434e+10,
#        2.7118334e+10, 3.5311436e+10, 3.6056994e+10, 2.2953966e+10,
#        1.6712308e+10, 2.0470798e+10, 2.7361722e+10, 3.4266771e+10,
#        3.3337061e+10, 3.8166315e+10, 3.9014294e+10, 3.4464903e+10,
#        3.4509218e+10, 3.7703348e+10, 3.7254099e+10, 3.6100665e+10,
#        2.8897331e+10, 3.8676984e+10, 4.2138268e+10, 3.2360606e+10,
#        2.5418285e+10, 3.2340419e+10, 3.6997448e+10, 2.9615794e+10,
#        2.6749608e+10, 4.0973570e+10, 4.6318465e+10, 4.0383185e+10,
# ...

# %%
s
# Out:
# array([0.        , 0.00390625, 0.0078125 , 0.01171875, 0.015625  ,
#        0.01953125, 0.0234375 , 0.02734375, 0.03125   , 0.03515625,
#        0.0390625 , 0.04296875, 0.046875  , 0.05078125, 0.0546875 ,
#        0.05859375, 0.0625    , 0.06640625, 0.0703125 , 0.07421875,
#        0.078125  , 0.08203125, 0.0859375 , 0.08984375, 0.09375   ,
#        0.09765625, 0.1015625 , 0.10546875, 0.109375  , 0.11328125,
#        0.1171875 , 0.12109375, 0.125     , 0.12890625, 0.1328125 ,
#        0.13671875, 0.140625  , 0.14453125, 0.1484375 , 0.15234375,
#        0.15625   , 0.16015625, 0.1640625 , 0.16796875, 0.171875  ,
#        0.17578125, 0.1796875 , 0.18359375, 0.1875    , 0.19140625,
#        0.1953125 , 0.19921875, 0.203125  , 0.20703125, 0.2109375 ,
#        0.21484375, 0.21875   , 0.22265625, 0.2265625 , 0.23046875,
#        0.234375  , 0.23828125, 0.2421875 , 0.24609375, 0.25      ,
#        0.25390625, 0.2578125 , 0.26171875, 0.265625  , 0.26953125,
# ...

# %%
# VLF (0-0.04Hz)- Very low frequency band
# LF (0.04-0.15Hz)- Low frequency band
# HF (0.15-0.4Hz)- High frequency band
# Total Power- Total power of the spectrum
# LF/HF ratio
# Normalized LF & Normalized HF
# HF norm= HF/ (TP-VLF)*100= HF/ (LF+HF)*100
# LF norm= LF/ (TP-VLF)*100= LF/ (LF+HF)*100

# %%
vl_freq=s[0:10]

# %%
vl_pxx_den=pxx_den[0:10]

# %%
l_freq=s[11:38]

# %%
l_pxx_den=pxx_den[11:38]

# %%
h_freq=s[39:103]

# %%
h_pxx_den=pxx_den[39:103]

# %%
from scipy import integrate as intg

# %%
total_integral=intg.trapz(pxx_den,s)

# %%
total_integral
# Out:
# 12.048892624676228

# %%
vlf=intg.trapz(vl_pxx_den,vl_freq)

# %%
vlf
# Out:
# 0.8937477469444275

# %%
lf=intg.trapz(l_pxx_den,l_freq)

# %%
lf
# Out:
# 2.488808035850525

# %%
hf=intg.trapz(h_pxx_den,h_freq)

# %%
hf
# Out:
# 5.993108868598938

# %%
LFHF=lf/hf

# %%
LFHF
# Out:
# 0.41527829552550005

# %%
HF_norm= hf/ (total_integral-vlf)*100

# %%
HF_norm
# Out:
# 53.7250652885965

# %%
LF_norm= lf/ (total_integral-vlf)*100

# %%
LF_norm
# Out:
# 22.310853540044562

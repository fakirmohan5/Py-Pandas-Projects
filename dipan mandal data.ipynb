# %%
ecg_data='1114109,1376256,1900547,-196607,-786429,-589824,-786430,-786429,-786429,-720894,-655357,-655358,-720894,-720894,-720895,-720896,-655358,-458752,-196607,3,-65533,65537,196608,131073,65536,3,3,65536,3,1,65538,262144,131074,196610,262146,196611,327682,327682,458755,458752,262147,262146,327680,393217,458755,3,786432,3342338,2359297,458755,262146,327680,262144,262144,196610,196610,262144,131074,131072,65536,-65533,65536,589827,589827,524290,458755,458753,327683,327681,327680,196608,131073,2,-65534,-131069,-196607,-262141,-196607,-262144,-458749,-458751,-720893,-786431,-786430,-1179646,-851968,1835009,786433,-1310719,-1638398,-1769471,-1966079,-2031615,-2162685,-2162685,-2293758,-2424832,-2490365,-2490367,-2490366,-2490366,-2490367,-2293759,-2162688,-2228221,-2228222,-2293759,-2359294,-2359294,-2359295,-2359296,-2424829,-2424830,-2424829,-2424831,-2490365,-2424831,-2424829,-2424832,-2424829,-2293759,-2293759,-2359294,-2359296,-2424831,-2424832,-2424832,-2424832,-3014653,-786429,327683,-917503,-2686975,-2752512,-2818048,-2949119,-2883584,-2818048,-2818048,-2883581,-2883581,-2818048,-2883583,-2818047,-2686976,-2621439,-1900542,-1835006,-1769472,-1835005,-1769472,-1769471,-1703936,-1638397,-1572864,-1572861,-1441792,-1310719,-1245184,-1245181,-1114109,-983037,-786432,-851965,-851966,-851965,-786431,-786431,-720894,-1310718,655361,1966083,1245187,-655360,-983037,-917504,-1048574,-983038,-983038,-917504,-917503,-851967,-851965,-851965,-786429,-655359,-589824,-327678,-131069,65537,65538,65536,65538,65539,131072,131072,3,1,-65533,0,-65536,-131071,-65535,-131071,-131070,-65535,-65536,-131071,-196608,-196608,-327677,-458751,-393213,-720896,-1114112,393216,2162690,131074,-720895,-1179645,-1245183,-1376253,-1441791,-1441792,-1572861,-1638399,-1703933,-1703935,-1769469,-1703936,-1638400,-1179645,-1179647,-1245183,-1179648,-1245184,-1245184,-1310718,-1245183,-1245184,-1310719,-1245184,-1310720,-1376254,-1310720,-1310719,-1245184,-1310717,-1376253,-1376253,-1376256,-1310718,-1179648,-1769470,-720895,1310720,983042,-1179645,-1835008,-1835007,-1900543,-1966078,-1966077,-1900544,-1900543,-1966078,-2031614,-2031614,-2031613,-1900541,-1835005,-1703936,-1507326,-1310717,-1245181,-1245181,-1179648,-1179646,-1179647,-1179647,-1179645,-1114111,-1114110,-1114110,-1048576,-1048576,-1048574,-1048573,-1048574,-917502,-917502,-983037,-983037,-983038,-983039,-917503,-851967,-1179647,-458749,1966080,1048579,-786429,-1114111,-983039,-1114109,-1114109,-1114109,-1048573,-917503,-917503,-983038,-851967,-786430,-786430,-655357,196609,196609,196608,196609,196610,196611,262144,262144,196608,196609,196609,262144,262144,262145,393217,458755,393219,393218,393217,393218,327682,458752,262145,327683,2883586,3342337,1376258,262146,196608,131072,65539,65537,2,-65534,1,-65536,-65534,3,0,65537,196609,393219,524291,655362,655361,524291,589824,655360,655361,655362,655361,589826,524288,458753,393218,393218,524289,589827,720898,851968,720899,720897,589825,458755,524288,3,327682,2686977,1835011,-65533,-327679,-327677,-524287,-655357,-720894,-786431,-851967,-1048573,-1048575,-1114109,-1114110,-1114112,-851967,-917501,-983037,-1048576,-1114111,-1114109,-1245181,-1376253,-1310720,-1376255,-1441790,-1441791,-1507326,-1507328,-1507327,-1507325,-1638397,-1638400,-1703935,-1769470,-1835007,-1703934,-1835006,-2359294,-196605,589826,-524286,-2162688,-2293757,-2424829,-2359294,-2359295,-2359295,-2359295,-2424831,-2490365,-2490366,-2490368,-2490365,-2424829,-2228221,-2097150,-1835007,-1703935,-1703935,-1703935,-1638399,-1572864,-1638400,-1638398,-1572863,-1507327,-1507327,-1507327,-1507325,-1376256,-1376254,-1376255,-1310720,-1310719,-1376255,-1310717,-1245182,-1245183,-1310720,-1310719,-1310717,-1376254,-1310717,-1310719,-1835006,262147,1245185,65537,-1572862,-1703934,-1638398,-1769470,-1703933,-1638398,-1703936,-1703933,-1769469,-1769471,-1835005,-1703936,-1638400,-786432,-720895,-720895,-720896,-655359,-655357,-655357,-655357,-589822,-524287,-524287,-524287,-458749,-458751,-458750,-458750,-393216,-393216,-393213,-262144,-196606,-262141,-196605,-131072,-131070,-131070,2,-327679,-327678,2031618,2359299,655361,-458749,-327678,-458749,-524285,-524286,-524288,-589823,-589821,-655357,-655360,-655360,-655359,-589821,-458751,-327678,-65535,3,0,3,2,-65534,0,1,-65533,-65535,1,2,1,0,2,2,0,1,2,65537,131072,3,1,2,-65535,-65534,-65536,131072,-393215,65538,1245184,2424832,524291,-393215,-262144,-458751,-458752,-524286,-524287,-655358,-720895,-720896,-786429,-720895,-655358,-131071,-196606,-131069,-65536,-65536,-131071,-131072,-65535,-65536,0,-65534,-65533,-65535,-65536,-65534,-131069,-131070,-131071,-131069,-65534,-65536,-131071,-131072,-196606,-196608,-262141,-327677,-655359,262146,2359299,851969,-131070,-655360,-720893,-786430,-851966,-851967,-851968,-917503,-917504,-1048575,-1048575,-983040,-983037,-851965,-589824,-524287,-393216,-393215,-458750,-524285,-524287,-524287,-524288,-524287,-524286,-524288,-589821,-589823,-589823,-655358,-655358,-655357,-655359,-720893,-655358,-655357,-655357,-655359,-720894,-720894,-655360,-720896,-589821,-983039,-720894,524289,1769474,-196605,-851967,-1048573,-1114111,-1114112,-1179645,-1179648,-1310717,-1310718,-1310719,-1376255,-1376256,-1310718,-1245183,-655360,-720894,-720896,-720895,-720895,-720896,-720896,-720894,-655360,-720894,-720893,-655359,-720893,-720894,-720894,-720894,-720894,-786429,-720894,-655357,-655357,-720894,-786431,-786431,-786430,-786430,-589823,-1245182,-196608,1245184,1572864,-589823,-1245181,-1245181,-1310720,-1310720,-1310720,-1376253,-1376253,-1376254,-1376255,-1376256,-1441789,-1310720,-1310719,-1179648,-1114109,-917503,-851967,-851966,-917501,-851967,-851967,-917503,-851967,-851966,-851965,-851967,-786429,-786429,-786431,-786431,-786430,-786430,-720896,-720896,-720894,-655359,-589823,-720893,-720894,-720895,-720896,-786429,-655360,-1048575,-720895,1835008,983042,-196606,-1048576,-1048576,-1179648,-1245184,-1245184,-1245184,-1245184,-1376253,-1376254,-1376253,-1310720,-1310717,-1245183,-786432,-786430,-851965,-786432,-851966,-851966,-786431,-786431,-786431,-786430,-720896,-720894,-720896,-786430,-720895,-720894,-720893,-589823,-524288,-655360,-720895,-720895,-786430,-786432,-720893,-1048574,-589821,589826,1769474,1,-1245181,-1245184,-1376256,-1441789,-1310720,-1376254,-1376255,-1310720,-1376255,-1310720,-1310717,-1179648,-1179645,-983040,-851965,-720893,-589824,-655360,-720893,-655360,-720895,-786430,-720894,-720896,-720894,-720894,-720896,-786430,-720896,-720894,-720896,-655360,-720893,-720895,-589824,-524287,-524288,-720896,-851968,-851966,-851965,-917502,-851965,-1507328,-851967,2097155,917506,-458750,-1376254,-1441791,-1572861,-1572861,-1638399,-1703936,-1769470,-1769471,-1835008,-1900543,-1966078,-1966078,-1966078,-1703936,-1769471,-1769472,-1835005,-1900542,-2097151,-2097152,-2162685,-2162686,-2162687,-2293758,-2293760,-2359294,-2424829,-2424831,-2490367,-2490367,-2555903,-2621439,-2621437,-2555903,-2686975,-2818046,-2818045,-2818048,-2883581,-2752511,-3145728,-3342334,-1441789,-196606,-2359295,-3080189,-3342334,-3407869,-3407870,-3407870,-3342336,-3407869,-3407869,-3473405,-3473407,-3473406,-3407872,-3342336,-3211262,-3014656,-2949118,-2752512,-2752510,-2686973,-2621439,-2686973,-2686974,-2621439,-2621437,-2621438,-2621439,-2555902,-2490368,-2555902,-2490368,-2490366,-2490366,-2490365,-2490365,-2490366,-2424831,-2359294,-2293760,-2293760,-2424829,-2424830,-2359296,-2359295,-2359293,-2424829,-2752511,-1507325,655361,65538,-2097150,-2490365,-2424832,-2490365,-2490366,-2359296,-2359296,-2359296,-2359293,-2359295,-2293758,-2228223,-2162688,-1572862,-1507327,-1507328,-1507326,-1507325,-1507326,-1507326,-1376256,-1310720,-1245184,-1245182,-1179648,-1179647,-1114110,-1179645,-1114111,-1114111,-1114109,-1048573,-983037,-917503,-1048575,-1114109,-1114110,-1114109,-1179645,-983040,-1638397,-1114110,1507328,983042,-983037,-1310717,-1179648,-1310717,-1310718,-1310717,-1245182,-1245184,-1245184,-1376254,-1376255,-1310720,-1376253,-1245182,-1048574,-851968,-786432,-655360,-655359,-655359,-655358,-655358,-655358,-655359,-655358,-655358,-720894,-655359,-720893,-655358,-589823,-655359,-655357,-655359,-655357,-589821,-524286,-524285,-589823,-655358,-655360,-720896,-589823,-720895,-1179646,983043,1900546,786434,-983037,-1114112,-1245181,-1376255,-1441790,-1441790,-1441792,-1638397,-1703934,-1769470,-1900542,-1966078,-2031613,-1900543,-2031615,-2097149,-2228223,-2359293,-2490365,-2555904,-2686973,-2752511,-2949117,-3014655,-3080189,-3211263,-3342333,-3407871,-3407872,-3473408,-3604477,-3670013,-3670015,-3866621,-3997696,-4063232,-4194302,-4194304,-4194304,-4915199,-2949117,-1835005,-2686975,-4653055,-4915199,-4915199,-5046269,-5177341,-5177344,-5177343,-5242880,-5308416,-5373949,-5373950,-5308414,-5177344,-5177341,-4980733,-4784125,-4718589,-4587520,-4587517,-4587519,-4587519,-4587519,-4456448,-4521981,-4456448,-4390912,-4325374,-4259839,-4194304,-4259838,-4128766,-3997696,-3932159,-3932158,-3801088,-3735552,-3538942,-3473408,-3538941,-3473406,-3473406,-3276800,-3145726,-3145725,-3670014,-1966077,-655357,-917502,-2818047,-3145728,-3080191,-3145727,-3080192,-3014655,-3014653,-2883584,-2883581,-2818048,-2818046,-2686973,-2555904,-2555902,-1703936,-1638399,-1638397,-1638398,-1572862,-1376256,-1376253,-1310720,-1310717,-1245181,-1179648,-1179645,-1114111,-1048573,-983040,-983039,-851968,-786431,-720894,-589823,-655359,-655358,-589823,-655357,-589823,-458751,-720893,-458751,2097153,2555904,720896,-524285,-524288,-589823,-589823,-458751,-458750,-393216,-458749,-393215,-393216,-393213,-262142,-196606,-65534,196610,327682,458754,589826,655360,655363,655362,655362,720896,720899,786434,786434,851968,851969,851971,917504,917506,917506,983040,983042,983041,983043,1179648,1179649,1114112,983043,1048576,1048576,1048579,1245184,1048577,655362,3014659,3473411,1310722,720896,655362,589824,589824,524291,524290,589824,524290,458755,458754,524289,524291,983043,983043,1048577,1048577,983043,917507,917505,917504,917504,917504,851970,851969,851969,786432,786433,786432,655361,655361,655361,720898,720897,589827,589824,524289,458754,458752,589825,2,1441793,3145731,1310723,65536,3,-65536,-196605,-262141,-262144,-327677,-327680,-458749,-524286,-589821,-524286,-458750,-262143,-65533,3,-65534,-65534,-65533,-65536,-131071,-131069,-65536,-65534,2,-131069,-131072,-65534,-131070,-65535,0,0,2,-65534,-65533,65537,65536,0,-65534,-131069,-131071,-131071,-131071,-262141,-458750,458752,2555907,1179649,-393214,-524286,-589824,-589823,-720894,-720895,-720894,-720895,-720895,-786430,-786430,-720895,-196607,-131070,-131072,-196605,-131072,-196605,-196606,-196606,-131070,-131070,-131072,-131069,-131070,-131069,-65536,-65533,0,-65533,1,-65533,3,3,1,-65534,-131069,-131070,-131072,65537,-589824,-327678,2031617,1966081,2,-524285,-524285,-655358,-720896,-720896,-720895,-786429,-720894,-786430,-786432,-851965,-851965,-720896,-524287,-393216,-262143,-262143,-262143,-262142,-262142,-262141,-262144,-262142,-262144,-262144,-262143,-196607,-196607,-196607,-196607,-262144,-196606,-196608,-262141,-262143,-196608,-196608,-196608,-131069,-196606,-262144,-262141,-327677,-327680,-131071,-262141,-851966,1376257,2490370,1310723,-524285,-720893,-720893,-786430,-786429,-786431,-851965,-851967,-851968,-917503,-917501,-917501,-917501,-786432,-327678,-327680,-393213,-393213,-327679,-327679,-393213,-458750,-393216,-393216,-393215,-458749,-458751,-458750,-458749,-458750,-458750,-458749,-458750,-393216,-327680,-262143,-327677,-327679,-393214,-524285,-458750,-524287,-458749,-917502,-196606,2031619,1310720,-458752,-851966,-786431,-917504,-917503,-917501,-917503,-917503,-917503,-917504,-983037,-851967,-851966,-786429,-589822,-458750,-393214,-327680,-327679,-393215,-393214,-393215,-458749,-393215,-458749,-458750,-458751,-524285,-458751,-458752,-458752,-458749,-458752,-524286,-524286,-524288,-458751,-393215,-262143,-327679,-524285,-524285,-589822,-589823,-589821,-589824,-1048576,131074,2883585,655362,-786432,-917503,-1048573,-1114110,-1114109,-1179645,-1179646,-1245182,-1245183,-1310717,-1310720,-1310717,-1310719,-1245182,-720894,-786429,-720895,-720896,-720893,-655360,-720894,-655360,-655358,-655360,-655360,-720893,-655359,-655359,-655360,-655360,-720894,-720894,-720893,-524287,-458750,-524285,-589822,-589823,-655358,-655359,-720893,-655359,-1114110,-262143,2293761,851971,-262144,-983040,-983038,-1048575,-983040,-1114111,-1114109,-1114111,-1114112,-1245182,-1310717,-1245184,-1310718,-1179648,-983038,-917501,-720896,-720894,-720893,-655357,-720893,-655359,-720893,-720895,-720894,-655360,-720894,-655360,-655359,-720895,-720895,-720896,-655358,-720894,-786429,-720894,-655358,-655360,-655360,-589823,-589824,-786430,-786432,-851965,-851966,-917502,-786431,-1114111,-917502,1441792,1703937,-196607,-1376254,-1376254,-1507325,-1572863,-1638397,-1638400,-1703934,-1703935,-1835005,-1835008,-1835005,-1769471,-1179647,-1179645,-1179646,-1245182,-1310717,-1310719,-1376253,-1310720,-1376253,-1376256,-1376255,-1376255,-1441789,-1441789,-1376255,-1441789,-1441790,-1441791,-1376256,-1376254,-1376254,-1376253,-1245183,-1310719,-1376254,-1376254,-1376253,-1376256,-1507325,-1310719,-1900541,-1441789,1179648,524290,-1441790,-1769470,-1835006,-1966077,-1966077,-1966077,-1966079,-2031615,-2031614,-2031614,-1966080,-2031613,-1966080,-1900542,-1769469,-1507328,-1441792,-1376253,-1376253,-1376253,-1376254,-1310720,-1310719,-1310718,-1310719,-1310718,-1310718,-1310718,-1245183,-1310717,-1245183,-1245184,-1310717,-1310717,-1310717,-1245184,-1245184,-1245182,-1179645,-1114110,-1114109,-1179647,-1179646,-1179645,-1245181,-1310719,-1114112,-1441790,-1245181,1048579,851971,-196606,-1441789,-1441791,-1572862,-1572864,-1572862,-1507326,-1507327,-1507328,-1572864,-1638397,-1572864,-1572861,-851968,-851967,-917501,-851967,-851966,-851967,-851966,-786430,-851966,-851966,-851965,-851966,-786432,-786431,-786432,-720896,-786430,-720896,-720896,-655357,-589823,-655357,-720894,-720895,-720896,-786430,-786432,-720894,-1048576,-589824,1638402,1048576,65536,-983040,-1048576,-1245182,-1245184,-1310718,-1310720,-1376254,-1376256,-1376255,-1441792,-1507326,-1507327,-1441791,-1310718,-1245184,-1245183,-1179646,-1179648,-1245184,-1310720,-1376256,-1441792,-1441792,-1507325,-1507328,-1572862,-1638399,-1769469,-1769471,-1835006,-1966078,-1966080,-2031616,-2162686,-2228222,-2293759,-2359295,-2359293,-2359293,-2490365,-2555904,-2686973,-2752511,-2818046,-2686976,-3145727,-3473407,-1048575,262145,-1114112,-3276797,-3342335,-3538941,-3538942,-3604477,-3604478,-3670013,-3670016,-3735549,-3801087,-3801088,-3801086,-3801085,-3670014,-3211263,-3145727,-3145728,-3211261,-3211261,-3145727,-3145728,-3145728,-3145726,-3080191,-3080192,-3080190,-3014656,-3080189,-2949120,-2949119,-2949120,-2883583,-2818047,-2818047,-2686975,-2555903,-2621439,-2752511,-2686974,-2686973,-2686973,-2555904,-2555901,-2949119,-2031613,655360,-1048574,-2621438,-2686973,-2752509,-2752510,-2686976,-2686975,-2686973,-2686974,-2621440,-2686973,-2621438,-2621437,-2621437,-2490368,-2293759,-2097149,-1966079,-1835007,-1900541,-1835008,-1835007,-1835008,-1835007,-1835006,-1835006,-1769470,-1638399,-1572864,-1572863,-1507325,-1441789,-1376254,-1310720,-1310719,-1310718,-1310717,-1310717,-1310717,-1245182,-1179648,-1048574,-1048575,-1114111,-1114109,-1114109,-1114109,-1114111,-917502,-1376253,-917504,589826,1966083,-393213,-1179648,-1179648,-1376253,-1310720,-1310717,-1310718,-1310719,-1310720,-1376254,-1376253,-1441789,-1310720,-1310719,-655359,-655358,-655359,-655360,-720893,-655359,-655360,-655358,-655358,-655358,-655358,-655359,-655358,-655360,-720893,-655359,-655358,-655360,-655360,-655357,-589824,-589824,-524288,-524286,-589822,-655357,-655359,-720893,-655359,-458751,-983040,-524285,2162691,2162691,-196605,-983038,-983038,-1048573,-1048575,-1114109,-1048574,-1048575,-1114111,-1114112,-1179647,-1179645,-1114112,-1048576,-983039,-720896,-589821,-458751,-458750,-458752,-458749,-458751,-458750,-458749,-393216,-458749,-393216,-393213,-393216,-393214,-327680,-327680,-393214,-327678,-393213,-393213,-327679,-393214,-327679,-327679,-393215,-458750,-524286,-458749,-458751,-393214,-983038,-65534,2293760,1900547,-262143,-851967,-851967,-851968,-786432,-851965,-917501,-917503,-983037,-983039,-1048573,-983040,-524287,-524285,-458752,-524286,-458752,-524288,-589822,-524288,-524288,-524286,-524287,-524285,-524285,-458750,-458750,-393215,-393216,-393215,-327679,-196608,-327678,-327680,-393213,-393214,-458750,-458752,-458752,-1114110,1114112,2162691,1048579,-720893,-983040,-1048575,-1114112,-1245181,-1245184,-1245184,-1376256,-1507325,-1507326,-1507328,-1638398,-1572864,-1507328,-1441792,-1245184,-1179647,-1179648,-1245183,-1310718,-1376256,-1441792,-1441790,-1507325,-1507326,-1572861,-1572862,-1638397,-1638397,-1638397,-1638398,-1507328,-1572864,-1703933,-1769469,-1703935,-1835007,-1966077,-2031613,-2097151,-2097151,-2097152,-1966077,-2555904,-2097149,720896,0,-2097152,-2359296,-2490365,-2621437,-2686974,-2686975,-2686976,-2752509,-2752511,-2818046,-2818048,-2883583,-2818046,-2686975,-2359293,-2359293,-2424831,-2424829,-2490365,-2490367,-2555904,-2621439,-2621437,-2621438,-2686974,-2686975,-2752509,-2752509,-2752509,-2818045,-2752512,-2686976,-2883581,-2949119,-2883584,-2949118,-3014654,-2883583,-3538943,-3604479,-1310718,-524288,-2883583,-3473407,-3538942,-3670014,-3670016,-3735549,-3735552,-3735552,-3801087,-3866623,-3866624,-3866623,-3866623,-3801085,-3604478,-3342335,-3276798,-3080189,-2949119,-3014653,-2949120,-2949120,-2949118,-2883581,-2818046,-2752512,-2686976,-2686975,-2686973,-2621438,-2555903,-2555901,-2490367,-2359296,-2293760,-2293757,-2359294,-2359295,-2359293,-2293760,-2228222,-2490367,-2752512,-1310719,458752,-1572861,-2424830,-2621437,-2686975,-2686976,-2686976,-2752509,-2752511,-2818048,-2883582,-2949117,-2949119,-2949117,-2883582,-2293759,-2359293,-2424831,-2490365,-2555901,-2621437,-2621439,-2621438,-2621437,-2686976,-2686976,-2752509,-2752509,-2686976,-2752509,-2752509,-2752509,-2752512,-2883581,-2818048,-2883582,-2949117,-2686976,-3211261,-3407872,-1835005,-262144,-2228223,-2949119,-3211262,-3342333,-3276800,-3342336,-3276800,-3342333,-3407869,-3342336,-3407871,-3342333,-3276800,-3276799,-3145726,-2818046,-2686974,-2490366,-2424830,-2424829,-2359294,-2359294,-2293759,-2293758,-2162688,-2097151,-2031614,-2031615,-1966079,-1900541,-1900543,-1900543,-1835008,-1703936,-1703935,-1703936,-1703933,-1638399,-1638397,-1572864,-1310719,-1835007,-1900544,65539,1048578,-983040,-1572864,-1441791,-1638398,-1507327,-1441791,-1376256,-1376255,-1376255,-1376255,-1376254,-1245183,-1245181,-327680,-262144,-262144,-131071,-131071,-65533,-65534,-65535,1,3,65536,3,2,3,131072,131073,131072,131075,262144,131075,131073,65539,131074,131072,393217,196608,-393213,1441795,2490368,1507330,-196607,-65536,-262141,-262142,-327678,-327678,-458749,-458752,-524287,-589823,-589822,-655358,-524288,-458750,-327677,-65535,-65534,3,65536,0,-65535,-65536,0,-131069,-65536,0,-131069,-65535,-65536,-65535,-65535,-131070,-65536,-65535,-131069,-131071,-131072,-196605,-196605,-262143,-131070,-589824,-589824,983043,1900544,1114113,-589822,-524287,-720893,-720894,-720895,-786431,-851967,-917502,-917503,-983039,-917503,-524285,-458750,-524286,-524286,-589821,-655357,-655360,-655359,-720893,-655360,-655359,-720893,-720893,-655360,-720893,-720893,-655360,-786429,-786432,-720895,-589824,-720896,-720896,-786429,-786429,-786430,-720893,-589824,-1310718,327681,1966080,1114115,-786430,-1048573,-1048574,-1114110,-1048575,-1048573,-1048574,-1048576,-1114111,-1114112,-1114109,-1048575,-1048576,-851966,-720895,-524286,-327680,-327678,-262141,-262141,-262143,-196608,-131071,-131072,-131072,-65536,-65535,-65536,-65536,2,1,0,3,2,2,1,65538,131073,196611,327681,327682,327681,327680,393216,262147,458753,196610,131075,2555906,2949122,1114115,131073,65537,-131069,1,-65534,-65536,-65534,-65535,-131070,-131070,-131070,393218,524290,589825,524288,524290,589824,589826,589826,524291,524289,524289,524288,458755,458754,458755,458752,458752,524288,524289,524288,524288,458753,458752,524291,589824,458755,524289,524288,458754,458754,524291,65539,1572865,2555906,2162690,524288,65538,-131069,-131071,-196605,-196605,-196607,-196607,-262141,-262143,-196605,-196607,-131069,65536,196608,131075,131074,131074,196608,131073,131074,131074,131073,196608,196610,196610,327680,196611,262144,262147,262145,327682,327681,327682,393218,458753,393216,262146,262145,196611,196610,327681,-131072,-196607,2031616,2883585,917505,262147,-131072,-262142,-262141,-196608,-262141,-327677,-262144,-262143,-262143,-327678,-327677,65539,65537,2,0,3,-65535,-65535,-65534,-65533,1,0,3,0,0,2,1,1,1,0,131073,131075,3,-131069,-65536,1,-131072,-65536,-327680,-131070,1507330,3145729,524289,-458750,-524287,-655357,-720893,-655358,-655357,-786429,-786429,-655360,-720893,-720894,-655358,-524286,-393214,-196608,-131072,-131070,-131072,-196607,-196605,-196605,-196607,-196607,-196608,-196608,-196608,-196605,-131070,-131071,-131071,-131069,-131070,-196605,-131071,-131070,-131069,0,2,-65535,-196606,-196607,-262141,-262144,-131069,-786431,-327677,2555907,1703938,-458751,-655359,-851966,-983039,-983040,-1048574,-1114112,-1179647,-1245181,-1310718,-1376256,-1376256,-1376256,-1376256,-1376256,-1376255,-1507328,-1638397,-1769469,-1835007,-1900542,-2031616,-2097152,-2228222,-2293758,-2359294,-2490367,-2621439,-2621439,-2752511,-2949117,-2949120,-3080189,-3145727,-3211262,-3276797,-3342336,-3473407,-3604477,-3735551,-3801086,-3932157,-3932160,-4521983,-3866622,-1441791,-2752509,-4521983,-4784125,-4784128,-4980736,-4980736,-4980736,-5046272,-5177344,-5177343,-5242878,-5308416,-5242878,-5242879,-5242879,-5111805,-4915199,-4915197,-4784128,-4849663,-4915198,-4980733,-4915199,-4915197,-4849661,-4784126,-4784127,-4718591,-4653054,-4653054,-4587519,-4521983,-4521984,-4390911,-4325375,-4390912,-4259838,-4194304,-4128768,-4063229,-3997694,-3932160,-3932157,-3932158,-3866622,-3866621,-3801088,-4128765,-3145728,-1114111,-1179647,-2883583,-3735552,-3604480,-3670014,-3538944,-3473406,-3407872,-3342336,-3276800,-3211261,-3080191,-3080191,-1835007,-1703934,-1638398,-1572861,-1507325,-1441792,-1441790,-1376253,-1245183,-1310717,-1310717,-1179648,-1179647,-1179646,-1114112,-1114110,-1048576,-1048575,-917503,-851967,-720895,-720894,-786429,-655358,-655359,-655358,-589822,-851968,-1179647,458752,2424834,458754,-393213,-851968,-851968,-851968,-851967,-851965,-786431,-786430,-720894,-720893,-655359,-655358,-524288,-327680,-131072,0,131072,196609,262146,262144,196610,262145,262145,262147,327683,393216,327683,458753,458754,458753,524288,524289,589825,589824,589824,655360,786434,786434,655362,655361,589826,589824,589826,786433,196608,2228227,3473408,2293763,524291,327681,196609,131075,131072,65539,65536,2,-65534,-65533,-65534,3,131072,655361,655361,589826,655362,589825,589827,655361,589825,655363,589825,589824,720896,655361,589826,655360,655360,655363,720898,720896,589826,589824,524290,458755,720898,65537,1507331,3276801,2555906,524289,262146,196608,65537,2,-65534,-65535,-131069,-131070,-196608,-196605,-131069,3,262146,393216,524291,524289,524291,589824,524290,524290,524288,458755,524290,589824,589825,524289,524288,524291,524290,524288,524289,655361,589825,524288,458754,458753,458752,327683,458755,-196605,1245185,2555905,2424832,327681,-131070,-196606,-196608,-262141,-327677,-327679,-458749,-524286,-524288,-589823,-589822,-524285,-65535,-131069,-65535,-65533,0,-131070,-65536,-131069,-131072,-65536,-131069,-196606,-131072,-131070,-131071,-131070,2,1,-65536,-131071,-196607,-196607,-262143,-196606,-524285,-327677,983041,2424832,458753,-720893,-655359,-720896,-851968,-851965,-786431,-851966,-917504,-1048575,-1048576,-1048575,-983039,-917503,-720896,-589822,-524285,-327680,-393214,-393214,-458752,-458751,-524286,-524288,-458750,-458749,-458751,-589821,-589822,-589822,-524285,-458750,-262144,-196605,-196605,-262143,-262141,-196608,-262144,-327678,-327680,-655357,327681,2490369,1114114,-458749,-655357,-655357,-851965,-851965,-786429,-786429,-720896,-786430,-851966,-917501,-983037,-917504,-393214,-393214,-393214,-393213,-327680,-393215,-393213,-327677,-327679,-327680,-327680,-327680,-327680,-262144,-327678,-327679,-262143,-196608,-131072,-196605,-262142,-262143,-262143,-327678,-262142,-524286,-851967,655363,2424835,720896,-196605,-720895,-720894,-786430,-786432,-720895,-786429,-720895,-786431,-851966,-786431,-786430,-786430,-720894,-524287,-458749,-327678,-262143,-262141,-262143,-262143,-327678,-327678,-327678,-393213,-393213,-393214,-327679,-393214,-327679,-327678,-393215,-393214,-327680,-262144,-262144,-262144,-327680,-393214,-458750,-589823,-458752,-720895,-458751,1572867,1441794,458754,-786431,-786429,-917502,-851966,-851968,-917502,-851968,-851965,-917501,-851967,-851965,-720895,-327677,-327678,-327679,-393215,-327680,-327678,-327680,-327677,-327678,-327678,-196608,-327678,-327679,-327677,-262144,-327680,-327680,-262143,-196608,-262144,-393216,-393214,-393216,-524286,-393214,-327677,-1048576,524291,2555906,1638402,-589823,-983038,-1114109,-1179647,-1179648,-1245181,-1310720,-1376255,-1441790,-1441792,-1572861,-1638398,-1638397,-1572863,-1507326,-1376253,-1245184,-1310719,-1310719,-1441790,-1507327,-1572864,-1572864,-1638398,-1703934,-1769472,-1900542,-1966077,-1966079,-1966079,-2097152,-2228223,-2293760,-2424831,-2490368,-2555903,-2621438,-2490367,-2621438,-2818047,-2818046,-2949120,-2949120,-3014656,-3145727,-3735552,-2883583,-327679,-2162685,-3276798,-3866624,-3932160,-4128767,-4194301,-4128766,-4063229,-4063232,-4128768,-4194304,-4194303,-4194303,-4194303,-4128767,-3604478,-3604477,-3604478,-3604479,-3670015,-3670016,-3670013,-3735549,-3670014,-3538943,-3473408,-3538941,-3473407,-3407871,-3407870,-3342333,-3342335,-3342336,-3276797,-3211263,-3276798,-3211262,-3145727,-3211263,-3145726,-3014653,-2949119,-2949120,-3014655,-3014654,-2883584,-2949118,-2686976,-3145725,-3407871,-1507327,1,-2097149,-2818045,-3014654,-3080190,-3014654,-3014653,-2949119,-3014653,-3014653,-2949119,-2949118,-2949120,-2949119,-2752510,-2621438,-2490365,-2293759,-2097149,-1900544,-1769472,-1835005,-1835006,-1835005,-1769472,-1703935,-1703933,-1638398,-1638397,-1638397,-1507326,-1507325,-1441792,-1376256,-1376254,-1310719,-1310718,-1245183,-1245183,-1310718,-1310719,-1310720,-1245184,-1179648,-1179646,-1114109,-1048574,-983039,-983040,-983039,-983037,-1048573,-786432,-1245184,-589822,786435,1703938,-327677,-1048574,-1048576,-1114109,-1114110,-1114112,-1179645,-1114111,-1114109,-1114111,-1114110,-1048576,-1114110,-589823,-458749,-458750,-524285,-524286,-393215,-393215,-458749,-393213,-327679,-262144,-262143,-262142,-262143,-327677,-262144,-327678,-196608,-262142,-262144,-262144,-327678,-262143,-327677,-262143,-196606,-131071,-196605,-196606,-196606,-262141,-262144,-327680,-393213,-786430,-393213,1900547,1048576,-65535,-983037,-720896,-983038,-1114111,-1310717,-1441791,-1507326,-1507327,-1638399,-1769471,-1769472,-1769470,-1703936,-1572864,-1507327,-1441790,-1310719,-1310719,-1310720,-1441792,-1441789,-1376254,-1507327,-1703934,-1703936,-1703936,-1769470,-1769470,-1835007,-1835008,-1900541,-1966078,-2031614,-1966078,-1966078,-2031614,-2031614,-2228222,-2228222,-2031615,-2097149,-2162688,-2228221,-2293758,-2228221,-2228222,-2097152,-2555901,-2424830,-1245181,393216,-1638397,-2752512,-2621439,-2555901,-2752509,-2883583,-2818047,-2621440,-2621438,-2621439,-2686973,-2752509,-2621440,-2621440,-1638399,-1769472,-1835005,-1638397,-1572864,-1572863,-1572862,-1638397,-1572862,-1572862,-1507328,-1507325,-1441792,-1441791,-1441790,-1310718,-1310719,-1310718,-1245183,-1179647,-1179646,-1179647,-1048576,-1114111,-1048576,-1048575,-1048574,-917503,-720893,-786429,-1572861,262144,2097154,1376256,-917501,-1114110,-1048574,-1048576,-1179646,-1114111,-1179645,-1310719,-1179648,-1114109,-1179645,-1245182,-1048573,-983039,-851967,-589821,-393215,-327677,-131069,-131072,-65533,2,3,1,-65533,2,-65533,-131070,-65535,-65535,-65536,-65535,-65535,-131069,0,0,1,1,1,65536,-65536,-65536,-131070,131072,-393215,-589822,917505,2424835,917506,-65533,-458751,-589823,-720894,-720894,-720895,-786430,-786432,-983038,-983038,-983039,-983039,-458750,-589822,-524285,-589821,-655358,-720895,-720896,-720895,-917503,-983037,-1048576,-1114110,-1114112,-1179647,-1245181,-1310718,-1376255,-1376253,-1376253,-1376255,-1572864,-1638399,-1638399,-1703935,-1966079,-1835005,-2162685,-2293758,196609,65538,-1245181,-2555903,-2621440,-2752512,-2818048,-2883582,-2949118,-2949118,-2949120,-3014656,-3080190,-3080191,-3080192,-3014653,-2752512,-2686976,-2555904,-2424832,-2490365,-2424830,-2359296,-2359296,-2424831,-2424829,-2293759,-2293758,-2228221,-2097151,-2031616,-2097149,-2031616,-1966080,-2031614,-2031613,-1966079,-1900542,-1835008,-1900542,-1900542,-1900544,-1900543,-1835008,-1703935,-2162687,-1048575,1048579,983041,-983040,-2031616,-1835007,-1966078,-2097151,-2031616,-2031613,-2031615,-1966079,-1966078,-1966079,-1900542,-1769470,-983037,-983040,-917502,-917502,-917502,-786431,-786432,-786430,-720895,-655359,-589824,-589822,-589824,-589821,-524288,-524286,-458750,-262144,-393214,-393216,-393216,-458751,-458751,-262144,-786429,131073,2555906,2490370,720897,-393213,-393216,-458752,-524287,-524287,-458752,-524285,-589821,-458750,-458750,-458751,-524287,-327680,-196606,65537,131072,131075,196608,262146,131073,196608,131074,196609,262144,196611,131072,196608,196610,262144,262145,196610,327681,196611,262147,393216,327682,327680,262146,262144,131072,327682,65539,262147,2949121,2424832,1179651,196608,3,-65536,2,-65534,0,65539,3,1,1,1,3,589827,589824,524289,589825,589824,589825,589824,589824,589824,524291,524290,524289,458754,458754,458752,458755,589824,589826,458754,458753,393219,458752,393218,327682,-65536,2686976,2949123,524288,0,0,-196608,-65536,-131070,-262144,-262141,-196607,-262144,-327678,-262142,-196608,-131070,65539,262144,262146,262145,262146,262147,196611,262145,262144,262145,262144,131074,65537,2,65538,65537,-65534,0,3,65537,65536,-65533,-262143,-262143,-196608,-327679,-393215,-458750,-917503,-65536,2162691,1769473,-458752,-1179647,-1310718,-1441792,-1507328,-1638399,-1703935,-1900543,-2031616,-2228224,-2359295,-2424832,-2228221,-2424830,-2424832,-2555902,-2752509,-2752511,-2883583,-2949120,-3145726,-3211263,-3276799,-3342335,-3342336,-3473408,-3473407,-3473405,-3473406,-3604480,-3801088,-3801086,-3801085,-3866622,-3932157,-4063230,-4063231,-4063230,-4128767,-3932158,-4456446,-4521981,-2359296,-1835006,-3866624,-4390912,-4521982,-4653056,-4587518,-4587517,-4587519,-4653055,-4653055,-4653053,-4718590,-4718591,-4718589,-4587520,-4456445,-4259837,-4128766,-3932159,-3932157,-3801086,-3801085,-3801087,-3801086,-3735550,-3604477,-3538943,-3473408,-3407872,-3407869,-3276800,-3276797,-3211263,-3211262,-3080192,-2949120,-2949118,-2818045,-2818048,-2818046,-2555901,-2424832,-2424832,-2424830,-2424830,-2293760,-2359293,-2228222,-2097151,-2490368,-393215,655361,-393213,-2031615,-2228221,-2097152,-2162686,-2097152,-2097150,-2097150,-2031613,-2031615,-2031615,-1966079,-1966079,-1900542,-1900542,-1310717,-1376253,-1376254,-1376255,-1310720,-1310719,-1310720,-1376254,-1376255,-1441789,-1441790,-1441791,-1376256,-1376255,-1376255,-1376256,-1376255,-1310720,-1376256,-1376254,-1310719,-1310719,-1310718,-1310717,-1441789,-1441789,-1441791,-1310718,-1310718,-1769469,3,1179651,524288,-1376253,-1703933,-1769472,-1769472,-1769471,-1835005,-1769471,-1835005,-1769471,-1835007,-1835006,-1703936,-1638399,-1507325,-1376254,-1179645,-1048576,-1048576,-1114110,-1048575,-983039,-983039,-983040,-983040,-917504,-983037,-851968,-917501,-851968,-851966,-851965,-786432,-786432,-720893,-655358,-655360,-524288,-458750,-524286,-589821,-589824,-655359,-720894,-524288,-917504,-458750,851970,2031619,196611,-458751,-917504,-1048575,-1048573,-983039,-983038,-917501,-917501,-917504,-917504,-1048573,-983038,-917501,-327679,-262142,-196606,-131070,-131070,-65536,-65534,-65535,65536,65537,3,65537,131072,65539,131072,131074,131073,65537,65536,131073,196608,196609,196609,262147,262145,196610,196608,196609,131075,327680,-262144,589827,3211266,2949121,655361,0,65536,-65533,1,-65536,-131070,-131071,-131071,-65536,-131071,-131071,-131071,3,196610,327683,524288,524289,458755,458755,524290,589824,524290,589826,589825,524291,524290,589827,589827,655360,589826,655360,589826,524290,589825,589825,655361,720897,589826,589825,589824,589824,589824,589827,393219,196610,3014659,3014657,1638402,262145,131075,-65533,-65536,-65533,1,-65534,-131072,-131069,-196605,-196606,-65536,458752,393217,393218,393217,458753,327683,327682,393216,393216,393217,327681,393216,393217,393216,393218,393216,327680,262147,262147,393217,393219,393216,262147,327682,262146,196610,327680,-131072,327680,1703936,2883584,655361,-196608,-262143,-393213,-327678,-327679,-393215,-458752,-458752,-524285,-524288,-655359,-589824,-524287,-327677,-131072,0,-65535,-65533,0,-65534,-65533,1,-65534,-65534,-65534,-65534,0,-65534,0,-65533,-65533,-65534,-65536,-65535,-196607,-196607,-65535,-65536,-262142,-262144,-262142,-327680,-458749,-393214,-720896,-655360,1835009,2228225,131073,-1114109,-1114112,-1310720,-1376256,-1376255,-1507326,-1507328,-1638398,-1703933,-1835005,-1769470,-1769469,-1376255,-1310719,-1441789,-1441790,-1441791,-1441792,-1441792,-1507327,-1572863,-1572862,-1572864,-1703933,-1638400,-1638399,-1638398,-1638398,-1703933,-1703935,-1703935,-1769469,-1769471,-1703934,-1703934,-1769469,-1835007,-1966078,-1835008,-1966077,-1835006,-2424831,-1441789,-65536,458752,-1507325,-2097151,-2293758,-2359294,-2359295,-2359293,-2228224,-2359294,-2424831,-2424832,-2490365,-2490368,-2359296,-2359294,-2162685,-1900544,-1835008,-1638400,-1638399,-1572864,-1572863,-1572864,-1572862,-1572862,-1572862,-1507325,-1507325,-1441790,-1376255,-1376255'

# %%
y=ecg_data.split(',')

# %%
ecg_time='0.003,0.018,0.032,0.046,0.059,0.073,0.086,0.100,0.114,0.127,0.141,0.154,0.168,0.181,0.195,0.208,0.222,0.235,0.249,0.264,0.278,0.293,0.307,0.322,0.336,0.351,0.366,0.380,0.395,0.409,0.477,0.492,0.506,0.521,0.535,0.550,0.565,0.579,0.594,0.608,0.623,0.637,0.652,0.667,0.681,0.696,0.710,0.725,0.740,0.754,0.769,0.783,0.798,0.812,0.827,0.842,0.856,0.871,0.885,0.900,0.915,0.929,0.944,0.958,0.973,0.987,1.002,1.017,1.031,1.046,1.060,1.075,1.090,1.104,1.118,1.131,1.145,1.158,1.172,1.185,1.199,1.212,1.226,1.240,1.253,1.267,1.281,1.296,1.309,1.323,1.336,1.350,1.364,1.377,1.391,1.404,1.418,1.431,1.445,1.458,1.472,1.485,1.499,1.512,1.526,1.540,1.553,1.567,1.580,1.594,1.607,1.621,1.634,1.648,1.715,1.728,1.742,1.755,1.769,1.782,1.796,1.809,1.823,1.836,1.850,1.864,1.877,1.891,1.904,1.918,1.932,1.946,1.959,1.973,1.986,2.000,2.014,2.027,2.041,2.054,2.068,2.081,2.095,2.108,2.122,2.135,2.149,2.162,2.176,2.190,2.203,2.217,2.230,2.244,2.257,2.271,2.284,2.298,2.311,2.325,2.339,2.352,2.366,2.379,2.393,2.406,2.420,2.433,2.447,2.460,2.475,2.490,2.504,2.518,2.531,2.545,2.558,2.572,2.585,2.599,2.612,2.626,2.640,2.653,2.667,2.680,2.694,2.707,2.721,2.735,2.750,2.765,2.779,2.794,2.808,2.823,2.837,2.852,2.867,2.934,2.949,2.962,2.977,2.991,3.004,3.019,3.033,3.047,3.060,3.074,3.087,3.101,3.115,3.128,3.142,3.156,3.171,3.185,3.199,3.212,3.226,3.240,3.253,3.267,3.280,3.294,3.307,3.321,3.334,3.348,3.361,3.375,3.389,3.402,3.416,3.429,3.443,3.456,3.470,3.483,3.497,3.510,3.524,3.537,3.551,3.565,3.578,3.592,3.605,3.619,3.632,3.646,3.659,3.673,3.686,3.701,3.716,3.729,3.743,3.756,3.770,3.783,3.797,3.810,3.824,3.837,3.851,3.865,3.878,3.892,3.905,3.919,3.932,3.946,3.959,3.973,3.986,4.000,4.014,4.027,4.041,4.054,4.068,4.135,4.149,4.162,4.176,4.190,4.203,4.217,4.230,4.244,4.257,4.271,4.284,4.298,4.311,4.325,4.339,4.353,4.368,4.381,4.395,4.408,4.422,4.435,4.449,4.462,4.476,4.490,4.503,4.517,4.530,4.544,4.557,4.572,4.586,4.601,4.616,4.630,4.645,4.659,4.674,4.689,4.703,4.718,4.732,4.747,4.761,4.776,4.791,4.805,4.820,4.834,4.849,4.864,4.878,4.893,4.907,4.922,4.936,4.951,4.966,4.980,4.995,5.009,5.024,5.039,5.053,5.068,5.082,5.097,5.111,5.126,5.141,5.155,5.170,5.184,5.199,5.214,5.228,5.243,5.257,5.272,5.286,5.354,5.369,5.383,5.398,5.412,5.427,5.442,5.456,5.471,5.485,5.500,5.515,5.529,5.544,5.558,5.573,5.587,5.602,5.617,5.631,5.645,5.658,5.672,5.685,5.699,5.712,5.726,5.740,5.753,5.767,5.780,5.794,5.807,5.821,5.834,5.848,5.861,5.875,5.889,5.902,5.916,5.929,5.943,5.956,5.970,5.983,5.997,6.010,6.024,6.037,6.051,6.065,6.078,6.092,6.105,6.119,6.132,6.147,6.160,6.174,6.187,6.201,6.215,6.228,6.242,6.255,6.269,6.282,6.296,6.309,6.323,6.336,6.350,6.364,6.377,6.391,6.404,6.418,6.431,6.445,6.458,6.472,6.485,6.499,6.512,6.526,6.540,6.606,6.620,6.633,6.647,6.660,6.674,6.687,6.701,6.715,6.728,6.742,6.755,6.769,6.782,6.796,6.809,6.824,6.839,6.853,6.867,6.880,6.894,6.907,6.921,6.934,6.948,6.961,6.975,6.989,7.002,7.016,7.029,7.043,7.056,7.070,7.083,7.097,7.110,7.124,7.137,7.151,7.165,7.178,7.192,7.205,7.219,7.232,7.246,7.259,7.273,7.286,7.300,7.314,7.327,7.341,7.354,7.368,7.381,7.396,7.409,7.423,7.437,7.452,7.467,7.480,7.494,7.507,7.521,7.534,7.548,7.561,7.575,7.589,7.602,7.616,7.629,7.643,7.656,7.670,7.684,7.699,7.714,7.728,7.743,7.757,7.772,7.786,7.801,7.816,7.830,7.845,7.859,7.927,7.942,7.956,7.971,7.985,8.000,8.015,8.029,8.044,8.058,8.073,8.087,8.102,8.117,8.131,8.145,8.159,8.174,8.189,8.203,8.217,8.230,8.244,8.257,8.271,8.284,8.298,8.311,8.325,8.339,8.352,8.366,8.379,8.393,8.406,8.421,8.435,8.449,8.462,8.477,8.492,8.506,8.521,8.535,8.550,8.565,8.579,8.593,8.606,8.620,8.633,8.648,8.662,8.676,8.690,8.703,8.717,8.730,8.744,8.757,8.772,8.786,8.801,8.815,8.828,8.842,8.855,8.869,8.882,8.896,8.909,8.923,8.936,8.950,8.964,8.977,8.991,9.004,9.018,9.031,9.045,9.058,9.072,9.085,9.099,9.112,9.126,9.140,9.153,9.167,9.180,9.194,9.260,9.274,9.287,9.301,9.315,9.328,9.342,9.355,9.369,9.382,9.396,9.409,9.423,9.436,9.450,9.464,9.478,9.493,9.506,9.520,9.533,9.547,9.560,9.574,9.587,9.601,9.615,9.628,9.642,9.655,9.669,9.682,9.696,9.709,9.723,9.736,9.750,9.764,9.777,9.791,9.804,9.818,9.831,9.845,9.858,9.872,9.885,9.899,9.912,9.926,9.940,9.953,9.967,9.980,9.994,10.007,10.021,10.034,10.048,10.061,10.075,10.090,10.104,10.118,10.131,10.145,10.158,10.172,10.185,10.199,10.212,10.226,10.240,10.253,10.267,10.280,10.294,10.307,10.321,10.334,10.348,10.361,10.375,10.389,10.402,10.416,10.429,10.443,10.456,10.470,10.483,10.497,10.510,10.577,10.591,10.604,10.618,10.631,10.645,10.658,10.672,10.685,10.699,10.712,10.726,10.740,10.753,10.767,10.780,10.795,10.809,10.823,10.836,10.850,10.864,10.877,10.891,10.904,10.918,10.931,10.945,10.958,10.972,10.985,10.999,11.012,11.026,11.040,11.053,11.067,11.080,11.094,11.107,11.121,11.134,11.148,11.161,11.175,11.189,11.202,11.216,11.229,11.243,11.256,11.270,11.283,11.297,11.310,11.324,11.337,11.351,11.365,11.379,11.394,11.408,11.422,11.435,11.449,11.462,11.476,11.490,11.503,11.517,11.530,11.544,11.557,11.571,11.584,11.598,11.611,11.625,11.639,11.652,11.666,11.679,11.693,11.706,11.720,11.733,11.747,11.760,11.774,11.787,11.801,11.868,11.881,11.895,11.908,11.922,11.935,11.949,11.962,11.976,11.990,12.003,12.017,12.030,12.044,12.057,12.071,12.085,12.100,12.113,12.127,12.141,12.154,12.168,12.181,12.195,12.208,12.222,12.235,12.249,12.262,12.276,12.290,12.303,12.317,12.330,12.344,12.357,12.371,12.384,12.398,12.411,12.425,12.438,12.452,12.466,12.479,12.493,12.506,12.520,12.533,12.547,12.560,12.574,12.587,12.601,12.615,12.628,12.642,12.655,12.669,12.682,12.696,12.709,12.723,12.736,12.750,12.763,12.777,12.791,12.804,12.818,12.831,12.845,12.858,12.872,12.885,12.899,12.912,12.926,12.940,12.953,12.967,12.980,12.994,13.007,13.021,13.034,13.048,13.061,13.075,13.088,13.102,13.116,13.129,13.196,13.209,13.223,13.236,13.250,13.263,13.277,13.291,13.304,13.318,13.331,13.345,13.358,13.372,13.385,13.399,13.412,13.427,13.442,13.455,13.469,13.482,13.496,13.509,13.523,13.536,13.550,13.563,13.577,13.591,13.604,13.618,13.631,13.645,13.658,13.672,13.685,13.699,13.712,13.726,13.740,13.753,13.767,13.780,13.794,13.807,13.821,13.834,13.848,13.861,13.875,13.888,13.902,13.916,13.929,13.943,13.956,13.970,13.983,13.997,14.010,14.025,14.040,14.053,14.067,14.080,14.094,14.107,14.121,14.134,14.148,14.161,14.175,14.188,14.202,14.216,14.229,14.243,14.256,14.270,14.283,14.297,14.310,14.324,14.337,14.351,14.365,14.378,14.392,14.405,14.419,14.432,14.499,14.512,14.526,14.540,14.553,14.567,14.580,14.594,14.607,14.621,14.634,14.648,14.661,14.675,14.688,14.702,14.717,14.731,14.746,14.759,14.773,14.786,14.800,14.813,14.827,14.841,14.854,14.868,14.881,14.895,14.908,14.922,14.935,14.949,14.962,14.976,14.990,15.003,15.017,15.030,15.044,15.057,15.071,15.084,15.098,15.111,15.125,15.138,15.152,15.166,15.179,15.193,15.206,15.220,15.233,15.247,15.260,15.274,15.287,15.301,15.315,15.328,15.342,15.355,15.369,15.382,15.396,15.409,15.423,15.436,15.450,15.463,15.477,15.491,15.504,15.518,15.531,15.545,15.558,15.572,15.585,15.599,15.612,15.626,15.640,15.653,15.667,15.680,15.694,15.707,15.721,15.734,15.801,15.815,15.828,15.842,15.855,15.869,15.882,15.896,15.909,15.923,15.936,15.950,15.963,15.977,15.991,16.004,16.018,16.031,16.045,16.058,16.072,16.085,16.099,16.112,16.126,16.140,16.153,16.167,16.180,16.194,16.207,16.221,16.234,16.248,16.261,16.275,16.288,16.302,16.316,16.329,16.343,16.356,16.370,16.383,16.397,16.410,16.424,16.437,16.451,16.465,16.478,16.492,16.505,16.519,16.532,16.546,16.559,16.573,16.586,16.600,16.615,16.629,16.644,16.657,16.671,16.684,16.698,16.711,16.725,16.738,16.752,16.766,16.779,16.793,16.806,16.820,16.834,16.849,16.863,16.878,16.893,16.907,16.922,16.936,16.951,16.966,16.980,16.995,17.009,17.024,17.038,17.053,17.121,17.135,17.150,17.165,17.179,17.194,17.208,17.223,17.237,17.252,17.267,17.281,17.296,17.310,17.325,17.340,17.354,17.369,17.383,17.398,17.412,17.427,17.442,17.456,17.471,17.485,17.500,17.515,17.529,17.544,17.558,17.573,17.587,17.602,17.617,17.631,17.646,17.660,17.675,17.690,17.704,17.719,17.733,17.748,17.762,17.777,17.792,17.806,17.821,17.835,17.850,17.865,17.879,17.894,17.908,17.923,17.937,17.952,17.967,17.981,17.996,18.010,18.025,18.040,18.054,18.069,18.082,18.096,18.109,18.123,18.136,18.150,18.163,18.177,18.191,18.204,18.218,18.232,18.247,18.261,18.276,18.291,18.305,18.319,18.332,18.347,18.361,18.376,18.390,18.403,18.418,18.484,18.499,18.513,18.528,18.543,18.557,18.572,18.586,18.601,18.616,18.630,18.644,18.657,18.671,18.684,18.698,18.711,18.726,18.741,18.755,18.769,18.782,18.796,18.809,18.823,18.836,18.850,18.863,18.877,18.891,18.904,18.918,18.931,18.945,18.958,18.972,18.985,18.999,19.012,19.026,19.040,19.053,19.067,19.080,19.094,19.107,19.122,19.136,19.151,19.166,19.180,19.195,19.209,19.224,19.238,19.253,19.267,19.280,19.294,19.308,19.322,19.335,19.350,19.365,19.379,19.393,19.406,19.420,19.433,19.447,19.460,19.474,19.487,19.501,19.515,19.528,19.542,19.555,19.569,19.582,19.596,19.609,19.623,19.636,19.650,19.663,19.677,19.691,19.704,19.718,19.731,19.745,19.758,19.772,19.785,19.799,19.812,19.879,19.893,19.906,19.920,19.933,19.947,19.960,19.974,19.987,20.001,20.015,20.028,20.042,20.055,20.069,20.083,20.098,20.112,20.126,20.140,20.153,20.167,20.180,20.194,20.207,20.221,20.234,20.248,20.261,20.275,20.288,20.302,20.316,20.329,20.343,20.356,20.370,20.383,20.397,20.410,20.424,20.437,20.451,20.465,20.478,20.492,20.505,20.519,20.532,20.546,20.559,20.573,20.586,20.600,20.613,20.627,20.641,20.654,20.668,20.681,20.695,20.708,20.722,20.736,20.751,20.765,20.778,20.792,20.805,20.819,20.832,20.846,20.859,20.873,20.886,20.900,20.913,20.927,20.941,20.954,20.968,20.981,20.995,21.008,21.022,21.035,21.049,21.062,21.076,21.090,21.103,21.117,21.130,21.144,21.157,21.171,21.184,21.251,21.265,21.278,21.292,21.305,21.319,21.332,21.346,21.359,21.373,21.386,21.400,21.413,21.427,21.441,21.455,21.470,21.484,21.498,21.511,21.525,21.538,21.552,21.566,21.579,21.593,21.606,21.620,21.633,21.647,21.660,21.674,21.687,21.701,21.715,21.728,21.742,21.755,21.769,21.782,21.796,21.809,21.823,21.836,21.850,21.863,21.877,21.891,21.904,21.918,21.931,21.945,21.958,21.972,21.985,21.999,22.012,22.026,22.040,22.053,22.067,22.080,22.095,22.109,22.123,22.136,22.150,22.163,22.177,22.191,22.204,22.218,22.231,22.245,22.258,22.272,22.285,22.299,22.312,22.326,22.340,22.353,22.367,22.380,22.394,22.407,22.421,22.434,22.448,22.461,22.475,22.488,22.502,22.516,22.529,22.543,22.609,22.623,22.636,22.650,22.663,22.677,22.691,22.704,22.718,22.731,22.745,22.758,22.772,22.785,22.799,22.812,22.826,22.841,22.855,22.869,22.882,22.896,22.909,22.923,22.936,22.950,22.963,22.977,22.991,23.004,23.018,23.031,23.045,23.058,23.072,23.085,23.099,23.112,23.126,23.140,23.153,23.167,23.180,23.194,23.207,23.221,23.234,23.248,23.261,23.275,23.288,23.302,23.316,23.329,23.343,23.356,23.370,23.383,23.397,23.410,23.424,23.437,23.451,23.465,23.479,23.494,23.507,23.521,23.534,23.548,23.561,23.575,23.588,23.602,23.616,23.629,23.643,23.656,23.670,23.683,23.697,23.710,23.724,23.737,23.751,23.765,23.778,23.792,23.805,23.819,23.832,23.846,23.859,23.873,23.886,23.900,23.913,23.927,23.994,24.007,24.021,24.034,24.048,24.061,24.075,24.088,24.102,24.116,24.129,24.143,24.156,24.170,24.183,24.197,24.210,24.225,24.240,24.253,24.267,24.280,24.294,24.307,24.321,24.334,24.348,24.361,24.375,24.388,24.402,24.416,24.429,24.443,24.456,24.470,24.483,24.497,24.510,24.524,24.537,24.551,24.565,24.578,24.592,24.605,24.619,24.632,24.646,24.659,24.673,24.686,24.700,24.713,24.727,24.741,24.754,24.768,24.781,24.795,24.808,24.822,24.836,24.851,24.866,24.879,24.893,24.906,24.920,24.933,24.947,24.960,24.974,24.987,25.001,25.015,25.028,25.042,25.055,25.069,25.082,25.096,25.109,25.123,25.136,25.150,25.163,25.177,25.191,25.204,25.218,25.231,25.245,25.258,25.272,25.285,25.299,25.366,25.379,25.393,25.406,25.420,25.433,25.447,25.460,25.474,25.487,25.501,25.515,25.528,25.542,25.555,25.569,25.583,25.597,25.610,25.624,25.637,25.651,25.665,25.678,25.692,25.705,25.719,25.732,25.746,25.759,25.773,25.786,25.800,25.813,25.827,25.841,25.854,25.868,25.881,25.895,25.908,25.922,25.935,25.949,25.962,25.976,25.990,26.003,26.017,26.030,26.044,26.057,26.071,26.084,26.098,26.111,26.125,26.138,26.152,26.166,26.179,26.193,26.206,26.221,26.234,26.248,26.261,26.275,26.288,26.302,26.316,26.329,26.343,26.356,26.370,26.383,26.397,26.410,26.424,26.437,26.451,26.465,26.478,26.492,26.505,26.519,26.532,26.546,26.559,26.573,26.586,26.600,26.613,26.627,26.641,26.654,26.668,26.681,26.695,26.761,26.775,26.788,26.802,26.816,26.829,26.843,26.856,26.870,26.883,26.897,26.910,26.924,26.937,26.951,26.965,26.979,26.994,27.007,27.021,27.034,27.048,27.061,27.075,27.088,27.102,27.116,27.129,27.143,27.156,27.170,27.183,27.197,27.210,27.224,27.237,27.251,27.265,27.278,27.292,27.305,27.319,27.332,27.346,27.359,27.373,27.386,27.400,27.413,27.427,27.441,27.454,27.468,27.481,27.495,27.508,27.522,27.535,27.549,27.562,27.576,27.590,27.603,27.617,27.631,27.646,27.659,27.673,27.686,27.700,27.713,27.727,27.741,27.754,27.768,27.781,27.795,27.808,27.822,27.835,27.849,27.862,27.876,27.890,27.903,27.917,27.930,27.944,27.957,27.971,27.984,27.998,28.011,28.025,28.038,28.052,28.119,28.132,28.146,28.159,28.173,28.186,28.200,28.213,28.227,28.241,28.254,28.268,28.281,28.295,28.308,28.322,28.335,28.350,28.365,28.379,28.393,28.406,28.420,28.433,28.447,28.460,28.474,28.487,28.501,28.514,28.528,28.542,28.555,28.569,28.582,28.596,28.609,28.623,28.636,28.650,28.663,28.677,28.691,28.704,28.718,28.731,28.745,28.758,28.772,28.785,28.799,28.812,28.826,28.839,28.853,28.867,28.880,28.894,28.907,28.921,28.935,28.950,28.964,28.978,28.992,29.005,29.019,29.032,29.046,29.059,29.073,29.086,29.100,29.113,29.127,29.141,29.154,29.168,29.181,29.195,29.208,29.222,29.235,29.249,29.262,29.276,29.289,29.303,29.317,29.330,29.344,29.357,29.424,29.437,29.451,29.464,29.478,29.492,29.505,29.519,29.532,29.546,29.559,29.573,29.586,29.600,29.613,29.627,29.642,29.656,29.670,29.683,29.697,29.710,29.724,29.737,29.751,29.764,29.778,29.792,29.805,29.819,29.832,29.846,29.859,29.873,29.886,29.900,29.913,29.927,29.941,29.954,29.968,29.981,29.995,30.008,30.022,30.035,30.049,30.062,30.076,30.089,30.103,30.117,30.130,30.144,30.157,30.171,30.184,30.198,30.211,30.225,30.238,30.252,30.266,30.279,30.293,30.306,30.320,30.333,30.347,30.360,30.374,30.387,30.401,30.414,30.428,30.442,30.455,30.469,30.482,30.496,30.509,30.523,30.536,30.550,30.563,30.577,30.591,30.657,30.671,30.684,30.698,30.711,30.725,30.738,30.752,30.766,30.779,30.793,30.806,30.820,30.833,30.847,30.860,30.874,30.888,30.902,30.916,30.929,30.943,30.956,30.970,30.983,30.997,31.010,31.024,31.037,31.051,31.064,31.078,31.092,31.105,31.119,31.132,31.146,31.159,31.173,31.186,31.200,31.213,31.227,31.241,31.254,31.268,31.281,31.295,31.308,31.322,31.335,31.349,31.362,31.376,31.389,31.403,31.417,31.430,31.444,31.457,31.471,31.484,31.498,31.511,31.525,31.538,31.552,31.566,31.579,31.593,31.606,31.620,31.633,31.647,31.660,31.674,31.687,31.701,31.714,31.728,31.742,31.755,31.769,31.782,31.796,31.862,31.876,31.889,31.903,31.917,31.930,31.944,31.957,31.971,31.984,31.998,32.011,32.025,32.038,32.052,32.066,32.079,32.094,32.108,32.122,32.135,32.149,32.162,32.176,32.189,32.203,32.217,32.230,32.244,32.257,32.271,32.284,32.298,32.311,32.325,32.338,32.352,32.367,32.381,32.396,32.410,32.425,32.439,32.454,32.469,32.483,32.498,32.512,32.527,32.542,32.556,32.571,32.585,32.600,32.614,32.629,32.644,32.658,32.672,32.686,32.701,32.716,32.729,32.744,32.757,32.771,32.784,32.798,32.811,32.825,32.838,32.852,32.866,32.879,32.893,32.906,32.920,32.934,32.949,32.963,32.978,32.993,33.007,33.022,33.036,33.050,33.064,33.132,33.146,33.160,33.175,33.189,33.204,33.218,33.232,33.247,33.260,33.274,33.287,33.301,33.314,33.328,33.342,33.355,33.369,33.383,33.398,33.412,33.426,33.439,33.453,33.467,33.480,33.494,33.507,33.521,33.534,33.548,33.561,33.575,33.588,33.602,33.616,33.629,33.643,33.656,33.670,33.683,33.697,33.710,33.724,33.737,33.751,33.764,33.778,33.792,33.805,33.819,33.832,33.846,33.859,33.873,33.886,33.900,33.913,33.927,33.941,33.954,33.969,33.983,33.998,34.011,34.025,34.038,34.052,34.066,34.079,34.093,34.106,34.120,34.133,34.147,34.160,34.174,34.187,34.201,34.214,34.228,34.242,34.255,34.269,34.282,34.296,34.309,34.323,34.336,34.351,34.366,34.380,34.395,34.409,34.477,34.492,34.506,34.521,34.535,34.550,34.564,34.579,34.594,34.608,34.623,34.637,34.652,34.667,34.681,34.696,34.710,34.725,34.739,34.754,34.769,34.783,34.798,34.811,34.826,34.841,34.855,34.870,34.884,34.898,34.911,34.925,34.939,34.954,34.969,34.983,34.998,35.012,35.027,35.042,35.056,35.071,35.085,35.100,35.114,35.129,35.144,35.158,35.173,35.187,35.202,35.217,35.231,35.246,35.260,35.275,35.289,35.304,35.319,35.333,35.348,35.362,35.377,35.392,35.406,35.421,35.435,35.450,35.464,35.478,35.492,35.505,35.519,35.532,35.546,35.559,35.573,35.586,35.600,35.613,35.628,35.643,35.657,35.672,35.686,35.701,35.716,35.730,35.745,35.759,35.774,35.788,35.803,35.818,35.885,35.900,35.914,35.929,35.944,35.958,35.973,35.987,36.002,36.017,36.031,36.046,36.060,36.075,36.089,36.103,36.117,36.131,36.146,36.160,36.175,36.188,36.202,36.216,36.229,36.243,36.256,36.270,36.283,36.297,36.310,36.324,36.338,36.353,36.368,36.382,36.397,36.411,36.426,36.441,36.455,36.470,36.484,36.499,36.513,36.528,36.543,36.557,36.572,36.586,36.601,36.616,36.630,36.645,36.658,36.673,36.687,36.701,36.716,36.729,36.743,36.757,36.772,36.786,36.800,36.813,36.827,36.841,36.854,36.868,36.881,36.895,36.908,36.922,36.935,36.949,36.962,36.976,36.989,37.003,37.017,37.030,37.044,37.057,37.071,37.084,37.098,37.111,37.125,37.138,37.152,37.166,37.179,37.193,37.259,37.273,37.286,37.300,37.313,37.327,37.342,37.356,37.371,37.384,37.398,37.411,37.425,37.438,37.452,37.466,37.480,37.495,37.508,37.522,37.535,37.549,37.562,37.576,37.589,37.603,37.617,37.630,37.644,37.657,37.671,37.684,37.698,37.711,37.725,37.738,37.752,37.766,37.779,37.793,37.806,37.820,37.833,37.847,37.860,37.874,37.887,37.901,37.914,37.928,37.942,37.955,37.969,37.982,37.996,38.009,38.023,38.036,38.050,38.063,38.077,38.091,38.104,38.118,38.131,38.145,38.158,38.172,38.185,38.199,38.212,38.226,38.239,38.253,38.267,38.280,38.294,38.307,38.321,38.334,38.348,38.361,38.375,38.388,38.402,38.416,38.429,38.443,38.456,38.470,38.483,38.497,38.510,38.524,38.537,38.604,38.618,38.631,38.645,38.658,38.672,38.685,38.699,38.712,38.726,38.739,38.753,38.767,38.780,38.794,38.807,38.821,38.834,38.848,38.861,38.875,38.888,38.902,38.916,38.929,38.943,38.956,38.970,38.983,38.997,39.010,39.024,39.037,39.051,39.064,39.078,39.092,39.105,39.119,39.132,39.146,39.159,39.173,39.186,39.200,39.213,39.227,39.241,39.254,39.268,39.281,39.295,39.308,39.322,39.335,39.349,39.362,39.376,39.389,39.403,39.417,39.431,39.446,39.460,39.474,39.487,39.501,39.514,39.528,39.542,39.555,39.569,39.582,39.596,39.609,39.623,39.636,39.650,39.663,39.678,39.693,39.707,39.722,39.736,39.751,39.766,39.780,39.795,39.809,39.824,39.838,39.853,39.868,39.935,39.950,39.964,39.979,39.994,40.008,40.023,40.037,40.052,40.067,40.081,40.096,40.110,40.125,40.139,40.154,40.169,40.183,40.198,40.212,40.227,40.242,40.256,40.271,40.285,40.300,40.314,40.329,40.344,40.358,40.373,40.387,40.402,40.417,40.431,40.446,40.460,40.475,40.489,40.504,40.519,40.533,40.548,40.562,40.577,40.592,40.606,40.621,40.635,40.650,40.664,40.679,40.694,40.708,40.723,40.737,40.752,40.767,40.781,40.796,40.810,40.825,40.839,40.854,40.869,40.883,40.898,40.911,40.925,40.938,40.952,40.966,40.980,40.995,41.009,41.024,41.038,41.053,41.068,41.082,41.097,41.111,41.126,41.141,41.155,41.223,41.237,41.252,41.267,41.281,41.296,41.310,41.325,41.339,41.354,41.369,41.383,41.398,41.412,41.427,41.441,41.455,41.470,41.484,41.499,41.512,41.526,41.539,41.553,41.567,41.580,41.594,41.607,41.621,41.634,41.648,41.661,41.676,41.689,41.704,41.719,41.733,41.747,41.761,41.775,41.788,41.803,41.817,41.830,41.844,41.857,41.871,41.884,41.899,41.913,41.928,41.942,41.955,41.969,41.982,41.996,42.009,42.023,42.037,42.052,42.067,42.080,42.094,42.107,42.121,42.134,42.148,42.161,42.175,42.188,42.202,42.216,42.229,42.243,42.256,42.270,42.283,42.297,42.310,42.324,42.337,42.351,42.364,42.378,42.392,42.405,42.472,42.485,42.499,42.512,42.526,42.539,42.553,42.567,42.580,42.594,42.607,42.621,42.634,42.648,42.661,42.675,42.689,42.704,42.719,42.732,42.746,42.759,42.773,42.786,42.800,42.813,42.827,42.841,42.854,42.868,42.881,42.895,42.908,42.922,42.935,42.949,42.962,42.976,42.989,43.003,43.017,43.030,43.044,43.057,43.071,43.084,43.098,43.111,43.125,43.138,43.152,43.166,43.179,43.193,43.206,43.220,43.233,43.247,43.260,43.275,43.289,43.304,43.318,43.331,43.345,43.358,43.372,43.385,43.399,43.412,43.426,43.439,43.453,43.467,43.480,43.494,43.507,43.521,43.534,43.548,43.561,43.575,43.588,43.602,43.616,43.629,43.643,43.656,43.670,43.736,43.750,43.763,43.777,43.791,43.804,43.818,43.831,43.845,43.858,43.872,43.885,43.899,43.912,43.926,43.939,43.953,43.968,43.982,43.997,44.010,44.024,44.037,44.051,44.064,44.078,44.092,44.105,44.119,44.132,44.146,44.159,44.173,44.186,44.200,44.213,44.227,44.241,44.254,44.268,44.281,44.295,44.308,44.322,44.335,44.349,44.362,44.376,44.389,44.403,44.417,44.430,44.444,44.457,44.471,44.484,44.498,44.511,44.525,44.539,44.554,44.569,44.582,44.596,44.609,44.623,44.636,44.650,44.663,44.677,44.691,44.704,44.718,44.731,44.745,44.758,44.772,44.785,44.799,44.812,44.826,44.839,44.853,44.867,44.880,44.894,44.907,44.921,44.934,44.948,44.961,44.975,44.988,45.055,45.069,45.082,45.096,45.109,45.123,45.136,45.150,45.163,45.177,45.190,45.204,45.218,45.231,45.245,45.258,45.272,45.285,45.299,45.312,45.326,45.339,45.353,45.367,45.380,45.394,45.407,45.421,45.434,45.448,45.461,45.475,45.488,45.502,45.515,45.529,45.543,45.556,45.570,45.583,45.597,45.610,45.624,45.637,45.651,45.664,45.678,45.692,45.705,45.719,45.732,45.746,45.759,45.773,45.786,45.800,45.813,45.827,45.840,45.854,45.868,45.881,45.895,45.908,45.922,45.935,45.949,45.962,45.977,45.990,46.004,46.018,46.031,46.045,46.058,46.072,46.085,46.099,46.112,46.126,46.139,46.153,46.167,46.180,46.194,46.207,46.221,46.234,46.248,46.261,46.275,46.288,46.302,46.315,46.329,46.343,46.356,46.370,46.383,46.397,46.410,46.424,46.437,46.451,46.464,46.478,46.545,46.558,46.572,46.585,46.599,46.612,46.626,46.639,46.653,46.667,46.680,46.694,46.707,46.721,46.734,46.748,46.761,46.776,46.790,46.804,46.818,46.831,46.845,46.858,46.872,46.885,46.899,46.912,46.926,46.939,46.953,46.967,46.980,46.994,47.007,47.021,47.034,47.048,47.061,47.075,47.088,47.102,47.115,47.129,47.143,47.156,47.170,47.183,47.197,47.210,47.224,47.237,47.251,47.264,47.278,47.292,47.305,47.319,47.332,47.346,47.359,47.373,47.386,47.400,47.413,47.427,47.440,47.454,47.469,47.483,47.498,47.511,47.525,47.538,47.552,47.565,47.579,47.593,47.606,47.620,47.633,47.647,47.660,47.674,47.687,47.701,47.714,47.728,47.742,47.755,47.769,47.782,47.796,47.809,47.823,47.836,47.850,47.863,47.877,47.890,47.904,47.918,47.931,47.945,48.011,48.025,48.038,48.052,48.065,48.079,48.093,48.106,48.120,48.133,48.147,48.160,48.174,48.187,48.201,48.214,48.228,48.243,48.256,48.270,48.283,48.297,48.310,48.324,48.337,48.351,48.364,48.378,48.392,48.405,48.419,48.432,48.446,48.459,48.473,48.486,48.500,48.513,48.527,48.540,48.554,48.568,48.581,48.595,48.608,48.622,48.635,48.649,48.662,48.676,48.689,48.703,48.717,48.730,48.744,48.757,48.771,48.784,48.798,48.811,48.825,48.838,48.852,48.867,48.881,48.896,48.909,48.923,48.936,48.950,48.963,48.977,48.990,49.004,49.018,49.031,49.045,49.058,49.072,49.085,49.099,49.112,49.126,49.139,49.153,49.167,49.181,49.196,49.210,49.225,49.239,49.254,49.269,49.282,49.297,49.364,49.379,49.394,49.408,49.422,49.436,49.451,49.465,49.480,49.495,49.509,49.524,49.538,49.552,49.567,49.580,49.594,49.608,49.623,49.637,49.652,49.665,49.679,49.693,49.706,49.720,49.733,49.747,49.760,49.774,49.787,49.801,49.814,49.828,49.842,49.855,49.869,49.882,49.896,49.909,49.923,49.936,49.950,49.963,49.977,49.990,50.004,50.018,50.031,50.045,50.058,50.072,50.085,50.099,50.112,50.126,50.139,50.153,50.167,50.180,50.195,50.209,50.223,50.236,50.250,50.263,50.277,50.290,50.304,50.318,50.331,50.345,50.358,50.372,50.385,50.399,50.412,50.426,50.439,50.453,50.467,50.480,50.494,50.507,50.521,50.534,50.548,50.561,50.575,50.588,50.655,50.669,50.682,50.696,50.709,50.723,50.736,50.750,50.763,50.777,50.790,50.804,50.818,50.831,50.845,50.858,50.872,50.886,50.901,50.914,50.928,50.942,50.955,50.969,50.982,50.996,51.009,51.023,51.036,51.050,51.063,51.077,51.090,51.104,51.118,51.131,51.145,51.158,51.172,51.185,51.199,51.212,51.226,51.239,51.253,51.267,51.280,51.294,51.307,51.321,51.334,51.348,51.361,51.375,51.388,51.402,51.415,51.430,51.445,51.459,51.474,51.487,51.501,51.514,51.528,51.542,51.555,51.569,51.582,51.596,51.609,51.623,51.636,51.650,51.663,51.678,51.693,51.707,51.722,51.736,51.751,51.765,51.780,51.795,51.809,51.824,51.838,51.906,51.921,51.935,51.950,51.964,51.979,51.994,52.008,52.023,52.037,52.052,52.067,52.081,52.096,52.110,52.125,52.139,52.154,52.169,52.183,52.198,52.212,52.227,52.242,52.256,52.271,52.285,52.300,52.314,52.329,52.344,52.358,52.373,52.387,52.402,52.417,52.431,52.446,52.460,52.475,52.489,52.504,52.519,52.533,52.548,52.562,52.577,52.592,52.606,52.621,52.635,52.650,52.664,52.679,52.694,52.708,52.723,52.737,52.752,52.767,52.781,52.796,52.809,52.824,52.837,52.851,52.864,52.878,52.892,52.905,52.919,52.932,52.946,52.960,52.975,52.989,53.004,53.019,53.033,53.048,53.062,53.077,53.092,53.106,53.121,53.188,53.203,53.218,53.232,53.247,53.261,53.276,53.290,53.305,53.320,53.333,53.347,53.360,53.374,53.387,53.401,53.414,53.429,53.444,53.458,53.472,53.485,53.499,53.512,53.526,53.539,53.553,53.567,53.580,53.594,53.607,53.621,53.634,53.648,53.661,53.675,53.688,53.702,53.715,53.729,53.743,53.756,53.770,53.783,53.797,53.810,53.824,53.837,53.851,53.864,53.878,53.892,53.905,53.919,53.932,53.946,53.959,53.973,53.986,54.000,54.013,54.027,54.040,54.054,54.068,54.081,54.095,54.108,54.122,54.135,54.149,54.162,54.176,54.189,54.203,54.217,54.230,54.244,54.257,54.271,54.284,54.298,54.311,54.325,54.338,54.352,54.365,54.379,54.393,54.406,54.420,54.433,54.447,54.460,54.474,54.487,54.501,54.514,54.581,54.595,54.608,54.622,54.635,54.649,54.662,54.676,54.689,54.703,54.717,54.730,54.744,54.757,54.771,54.784,54.799,54.812,54.826,54.839,54.853,54.867,54.880,54.894,54.907,54.921,54.934,54.948,54.961,54.975,54.988,55.002,55.015,55.029,55.043,55.056,55.070,55.083,55.097,55.110,55.124,55.137,55.151,55.164,55.178,55.192,55.205,55.219,55.232,55.246,55.259,55.273,55.286,55.300,55.313,55.327,55.340,55.354,55.368,55.381,55.395,55.408,55.423,55.437,55.452,55.465,55.479,55.493,55.506,55.520,55.533,55.547,55.560,55.574,55.587,55.601,55.614,55.628,55.642,55.655,55.669,55.682,55.696,55.709,55.723,55.736,55.750,55.763,55.777,55.790,55.804,55.818,55.831,55.845,55.858,55.925,55.938,55.952,55.965,55.979,55.993,56.006,56.020,56.033,56.047,56.060,56.074,56.087,56.101,56.114,56.128,56.143,56.157,56.172,56.185,56.199,56.212,56.226,56.239,56.253,56.267,56.280,56.294,56.307,56.321,56.334,56.348,56.361,56.375,56.388,56.402,56.415,56.430,56.445,56.459,56.474,56.488,56.503,56.518,56.532,56.547,56.561,56.576,56.590,56.605,56.620,56.634,56.649,56.663,56.678,56.693,56.707,56.722,56.736,56.751,56.765,56.780,56.794,56.808,56.823,56.837,56.852,56.867,56.881,56.896,56.910,56.925,56.938,56.952,56.965,56.980,56.994,57.007,57.021,57.035,57.050,57.064,57.079,57.094,57.108,57.123,57.137,57.152,57.167,57.181,57.196,57.210,57.225,57.239,57.254,57.322,57.336,57.351,57.365,57.380,57.395,57.409,57.424,57.438,57.453,57.468,57.482,57.497,57.511,57.526,57.540,57.555,57.570,57.584,57.599,57.613,57.628,57.643,57.657,57.672,57.686,57.701,57.714,57.728,57.742,57.755,57.770,57.784,57.799,57.813,57.828,57.843,57.857,57.872,57.886,57.901,57.915,57.930,57.945,57.959,57.974,57.988,58.003,58.018,58.032,58.047,58.061,58.076,58.090,58.105,58.120,58.134,58.149,58.163,58.177,58.192,58.206,58.221,58.235,58.249,58.262,58.276,58.289,58.303,58.317,58.330,58.344,58.357,58.371,58.384,58.398,58.411,58.425,58.438,58.453,58.468,58.482,58.497,58.511,58.526,58.540,58.555,58.570,58.584,58.599,58.613,58.628,58.643,58.710,58.725,58.739,58.754,58.769,58.782,58.796,58.810,58.825,58.838,58.852,58.865,58.879,58.893,58.906,58.920,58.933,58.948,58.962,58.977,58.990,59.004,59.018,59.031,59.045,59.058,59.072,59.085,59.099,59.112,59.126,59.139,59.153,59.167,59.180,59.194,59.207,59.221,59.234,59.248,59.261,59.275,59.288,59.302,59.315,59.329,59.343,59.356,59.370,59.383,59.397,59.410,59.424,59.437,59.451,59.464,59.478,59.492,59.505,59.519,59.532,59.546,59.559,59.574,59.588,59.602,59.615,59.629,59.643,59.656,59.670,59.683,59.697,59.710,59.724,59.737,59.751,59.764,59.778,59.792,59.805,59.819,59.832,59.846,59.859,59.873,59.886,59.900,59.913,59.927,59.940,59.954,59.968,59.981,59.995'

# %%
x=ecg_time.split(',')

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import numpy as np

# %%
import array as arr

# %%
len(x)
# Out:
# 4178

# %%
len(y)
# Out:
# 4178

# %%
x1 = arr.array('f',[])

# %%
x2 = arr.array('f',[])

# %%
y1 = arr.array('f',[])

# %%
y2 = arr.array('f',[])

# %%
for i in range(4178):
    x1.append(float(x[i]))

# %%
for i in range(100):
    x2.append(float(x[i]))

# %%
for i in range(4178):
    y1.append(float(y[i]))

# %%
for i in range(100):
    y2.append(float(y[i]))

# %%
plt.rcParams['figure.figsize']=(30,10)

# %%
plt.plot(x1,y1)

# %%
plt.plot(x2,y2)

# %%
# discrete Fourier transformed points were calculated and plotted
f=np.zeros(4178)
n=np.arange(4178)
for k in range (4178):
    f[k]=np.sum(y1*np.exp(-2j*np.pi*k*n/4178))
    
plt.plot(abs(f),'g',label='magnitude')
# Out:
# C:\Users\Fakir\AppData\Local\Temp/ipykernel_3600/4284433042.py:5: ComplexWarning: Casting complex values to real discards the imaginary part
#   f[k]=np.sum(y1*np.exp(-2j*np.pi*k*n/4178))

# %%
f2=np.zeros(100)
n2=np.arange(100)
for l in range (100):
    f2[l]=np.sum(y2*np.exp(-2j*np.pi*l*n2/100))
    

plt.plot(abs(f2),'g',label='magnitude')
# Out:
# C:\Users\Fakir\AppData\Local\Temp/ipykernel_3600/2151828078.py:4: ComplexWarning: Casting complex values to real discards the imaginary part
#   f2[l]=np.sum(y2*np.exp(-2j*np.pi*l*n2/100))

# %%
from scipy import signal

# %%
s1, Pxx_den1 = signal.welch(y1,fs=4178/60, nperseg=256,noverlap=256//2)

plt.yscale("log")

plt.semilogy(s1, Pxx_den1,'o-')

plt.xlabel('frequency [Hz]')

plt.ylabel('PSD [V**2/Hz]')

plt.show()

# %%
s, Pxx_den = signal.welch(y1,fs=1, nperseg=256,noverlap=256//2)

plt.semilogy(s,Pxx_den)

plt.xlabel('frequency [Hz]')

plt.ylabel('PSD [V**2/Hz]')

plt.show()

# %%
Pxx_den
# Out:
# array([2.55807665e+13, 1.41115211e+14, 6.21831615e+13, 8.32283659e+12,
#        1.48731881e+12, 4.37316800e+12, 5.31818506e+12, 9.27128158e+11,
#        3.34472217e+11, 5.54531881e+11, 2.68074903e+12, 6.11013886e+12,
#        4.12630699e+12, 1.11614034e+12, 6.62039233e+11, 1.24841479e+12,
#        2.39347407e+12, 2.32315421e+12, 1.43807807e+12, 8.10536993e+11,
#        7.67255052e+11, 1.02379441e+12, 1.10871170e+12, 9.95059958e+11,
#        1.11855390e+12, 1.13977944e+12, 1.47397188e+12, 1.53354397e+12,
#        1.49427375e+12, 1.43809079e+12, 1.42985488e+12, 1.74864676e+12,
#        1.32628532e+12, 1.21776623e+12, 1.08385049e+12, 8.71300923e+11,
#        1.11171024e+12, 1.04757022e+12, 7.30989789e+11, 8.28614115e+11,
#        7.00511224e+11, 7.49648216e+11, 1.04207673e+12, 8.14257471e+11,
#        8.47265071e+11, 8.25997394e+11, 7.24000899e+11, 9.35393034e+11,
#        1.02095369e+12, 7.68707133e+11, 9.26112612e+11, 6.73233437e+11,
# ...

# %%
len(Pxx_den)
# Out:
# 129

# %%
pxx_den = arr.array('f',[])

# %%
for i in range(129):
    pxx_den.append(float(np.log(Pxx_den[i])))

# %%
pxx_den
# Out:
# array('f', [30.872861862182617, 32.580596923828125, 31.761104583740234, 29.750024795532227, 28.027996063232422, 29.106508255004883, 29.302152633666992, 27.555356979370117, 26.53582000732422, 27.04138946533203, 28.617116928100586, 29.44097137451172, 29.048404693603516, 27.74089813232422, 27.218589782714844, 27.852895736694336, 28.503767013549805, 28.473947525024414, 27.99432945251465, 27.420963287353516, 27.366085052490234, 27.654537200927734, 27.734220504760742, 27.626068115234375, 27.743057250976562, 27.761856079101562, 28.01898193359375, 28.058603286743164, 28.03266143798828, 27.99433708190918, 27.98859405517578, 28.189863204956055, 27.913402557373047, 27.828039169311523, 27.71154022216797, 27.493253707885742, 27.736921310424805, 27.677494049072266, 27.317665100097656, 27.44301986694336, 27.275075912475586, 27.342870712280273, 27.672237396240234, 27.4255428314209, 27.46527862548828, 27.439857482910156, 27.30805778503418, 27.564231872558594, 27.651758193969727, 27.36797523498535, 27
# ...

# %%
plt.plot(s,pxx_den)

# %%
s
# Out:
# array([0.        , 0.00390625, 0.0078125 , 0.01171875, 0.015625  ,
#        0.01953125, 0.0234375 , 0.02734375, 0.03125   , 0.03515625,
#        0.0390625 , 0.04296875, 0.046875  , 0.05078125, 0.0546875 ,
#        0.05859375, 0.0625    , 0.06640625, 0.0703125 , 0.07421875,
#        0.078125  , 0.08203125, 0.0859375 , 0.08984375, 0.09375   ,
#        0.09765625, 0.1015625 , 0.10546875, 0.109375  , 0.11328125,
#        0.1171875 , 0.12109375, 0.125     , 0.12890625, 0.1328125 ,
#        0.13671875, 0.140625  , 0.14453125, 0.1484375 , 0.15234375,
#        0.15625   , 0.16015625, 0.1640625 , 0.16796875, 0.171875  ,
#        0.17578125, 0.1796875 , 0.18359375, 0.1875    , 0.19140625,
#        0.1953125 , 0.19921875, 0.203125  , 0.20703125, 0.2109375 ,
#        0.21484375, 0.21875   , 0.22265625, 0.2265625 , 0.23046875,
#        0.234375  , 0.23828125, 0.2421875 , 0.24609375, 0.25      ,
#        0.25390625, 0.2578125 , 0.26171875, 0.265625  , 0.26953125,
# ...

# %%
# VLF (0-0.04Hz)- Very low frequency band
# LF (0.04-0.15Hz)- Low frequency band
# HF (0.15-0.4Hz)- High frequency band
# Total Power- Total power of the spectrum
# LF/HF ratio
# Normalized LF & Normalized HF
# HF norm= HF/ (TP-VLF)*100= HF/ (LF+HF)*100
# LF norm= LF/ (TP-VLF)*100= LF/ (LF+HF)*100

# %%
vl_freq=s[0:10]

# %%
vl_pxx_den=pxx_den[0:10]

# %%
l_freq=s[11:38]

# %%
l_pxx_den=pxx_den[11:38]

# %%
h_freq=s[39:103]

# %%
h_pxx_den=pxx_den[39:103]

# %%
from scipy import integrate as intg

# %%
total_integral=intg.trapz(pxx_den,s)

# %%
total_integral
# Out:
# 13.226831376552582

# %%
vlf=intg.trapz(vl_pxx_den,vl_freq)

# %%
vlf
# Out:
# 1.0295964553952217

# %%
lf=intg.trapz(l_pxx_den,l_freq)

# %%
lf
# Out:
# 2.834629103541374

# %%
hf=intg.trapz(h_pxx_den,h_freq)

# %%
hf
# Out:
# 6.476993001997471

# %%
LFHF=lf/hf

# %%
LFHF
# Out:
# 0.4376458493420001

# %%
HF_norm= hf/ (total_integral-vlf)*100

# %%
HF_norm
# Out:
# 53.10214195155378

# %%
LF_norm= lf/ (total_integral-vlf)*100

# %%
LF_norm
# Out:
# 23.23993201626721
